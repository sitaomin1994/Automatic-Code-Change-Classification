# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import sys
from simplejson import JSONDecodeError
from collections import Counter 
import pprint 
import math
import argparse 
import os
import collections
import json
import re
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt 
import random
import time

# %%
def parse_json(filepath):
    """
    function used to parse json of each commit json file

    Args:
        filepath_list - list of filepaths

    Returns:
        files_json - list object contains parsed information

    """

    files_json = []

    # each commits
    files = os.listdir(filepath)
    for path in files:
        if os.stat(filepath + path).st_size != 0 and path != 'desktop.ini':
            with open(filepath + path, encoding="utf8") as f:
                data = json.load(f)
                files_list = []
                # each file in commits
                for file in data['files']:
                    # parse only cluster file
                    for key in file.keys():
                        if re.match('^.*_cluster$', key):
                            actions_list = []
                            actions = file[key]['actions']
                            # each action in file
                            for action in actions:
                                actions_list.append(action['root'])
                            files_list.append(actions_list)
            if len(files_list) != 0:
                files_json.append(files_list)
    # return
    return files_json


folder_path = 'C:\\Users\\ichel\\Desktop\\shared_ReFiles\\AllFiles_Research\\'
all_files = parse_json(folder_path)

# %%
def preprocess_roots(files_data):
    counting = {}
    for file_index, files in enumerate(files_data):
        for root_index, roots in enumerate(files):
            for action_index, actions in enumerate(roots):
                temp = actions.split(' at ')[0].strip()
                tempq = []
                if temp.startswith('INS'):
                    tempq.append('INS')
                    words = [temp.split('INS ')[1].split('to ')[0].strip()
                             ] + [temp.split('INS ')[1].split('to ')[-1].strip()]
                    for items in words:

                        items = items.split(': ')[0].strip()
                        tempq.append(items)
                    temp = '_'.join(tempq)

                if temp.startswith('UPDATE'):
                    temp = 'UPDATE'
                if temp.startswith('MOVE'):
                    temp2 = temp.split(' from ')[1].strip()
                    tempq.append('MOVE')
                    tempq.append(temp2.split(': ')[0].strip())
                    temp = '_'.join(tempq)

                if temp.startswith('DEL'):
                    tempq.append('DEL')
                    tempq.append(temp.split('DEL ')[1].split(': ')[0].strip())
                    temp = '_'.join(tempq)
                temp = temp.replace(" ", "_")
                counting[temp] = counting.get(temp, 0) + 1
                files_data[file_index][root_index][action_index] = temp
    dic = {}
    i = 0
    for k, v in counting.items():
        dic[k] = i  
        i += 1
    return dic, files_data, counting

# %%
dic, datas, freq_dict = preprocess_roots(all_files)
rev_dic = dict(zip(dic.values(), dic.keys()))

# %%
def actions2sentence(datas):
    data_total = []
    for files in datas:
        data4file = []
        for roots in files:
            sentence = ' '.join(roots)
            data4file.append(sentence)
        data_total.append(data4file)
    return data_total


training_data = actions2sentence(datas)

def get_seqlength(training_data):
    max_root_len = 0
    seqlength_list = []
    for items in training_data:
        for item in items:
            seqlength_list.append(len(item.split(" ")))
            if len(item.split(" ")) >  max_root_len: 
                max_root_len = len(item.split(" "))
    return max_root_len, seqlength_list

def plot_hist(seqlength_list): 
    plt.figure(figsize=(20,10))
    number_of_files = np.array(seqlength_list)
    bincount = np.bincount(seqlength_list)
    x = np.arange(1, len(bincount)+1)
    n, bins, patches = plt.hist(seqlength_list,x)

max_seqlength, sequence_list = get_seqlength(training_data)
print("<sample training data>: ", training_data[0])
plot_hist(sequence_list)
# Out:
# <sample training data>:  ['INS_MethodDeclaration_TypeDeclaration INS_MethodDeclaration_TypeDeclaration UPDATE INS_TagElement_TagElement INS_TextElement_TagElement INS_FieldAccess_ArrayAccess DEL_SimpleName', 'INS_TypeDeclaration_TypeDeclaration INS_FieldDeclaration_TypeDeclaration INS_MethodDeclaration_TypeDeclaration INS_MethodDeclaration_TypeDeclaration MOVE_TypeDeclaration INS_Javadoc_MethodDeclaration MOVE_Block INS_Javadoc_MethodDeclaration INS_SimpleType_MethodDeclaration UPDATE MOVE_MethodDeclaration INS_Modifier_FieldDeclaration INS_Modifier_FieldDeclaration INS_ExpressionStatement_Block UPDATE INS_QualifiedName_ReturnStatement INS_FieldAccess_Assignment INS_ClassInstanceCreation_Assignment INS_QualifiedName_MethodInvocation INS_QualifiedName_Assignment INS_QualifiedName_MethodInvocation INS_QualifiedName_MethodInvocation INS_QualifiedName_MethodInvocation INS_QualifiedName_MethodInvocation INS_QualifiedName_MethodInvocation DEL_Modifier DEL_SimpleName DEL_MethodInvocation DEL_SimpleName DEL_SimpleName DEL_SimpleName DEL_FieldAccess DEL_SimpleName DEL_SimpleName DEL_SimpleName DEL_SimpleName', 'INS_FieldAccess_Assignment INS_FieldAccess_MethodInvocation DEL_QualifiedName DEL_QualifiedName']

# %%
def check_index_strange_words(training_data):
    for i, item in enumerate(training_data):
        for j, file in enumerate(item):
            for k, action in enumerate(file.split()):
                index = dic.get(action)
                if index is None: # for debug 
                    print("==============================")
                    print(action) # for debug 
                    print('commits index: %d'%i)
                    print('file: %d'%j)
                    print('action: %d'%k)
check_index_strange_words(training_data)

# %%
def concat_train_data(training_data): 
    concat_data = ""
    tmp_list = []
    for items in training_data: 
        tmp_list += items
    concat_data = " ".join(tmp_list)
    return concat_data
    
def tokenize_train_data(concat_train_data, dic): 
    data = []
    for word in concat_train_data.split():
        index = dic.get(word)
        if index is None: # for debug 
            print(word) # for debug 
        data.append(index)
    return data

tokenized_data = concat_train_data(training_data)
print(type(tokenized_data))
tokenized_data = tokenize_train_data(tokenized_data, dic)
print(tokenized_data[:10])
# Out:
# <class 'str'>
# [316, 316, 529, 214, 270, 2, 445, 880, 623, 316]

# %% [markdown]
# ## Subsampling
# Here we apply subsampling to get rid of roots such as "UPDATE", "INS_Method", which show up frequently in the dataset
# and could affect training speed and also the quality if the embeddings. The subsampling employed here is by Mikolov the creator of word2vec. For each root ri in the training set, we discard it with probability given by p(ri) = 1 - sqrt(1/(f(ri)).

# %%
def subsample(tokenized_data): 
    """
    Remove frequently occuring roots for faster training and better representation. 
    For the subsampling I am implementing Mikolov's negative.
    For each root ri it will discard it with the given probability p(ri) = 1 - sqrt(1/(f(ri)).
    :param tokenized_data: A list that contains the position in of each root in all commits into a single document 
    """
    threshold = 1e-5
    roots_count = Counter(tokenized_data)
    total_count = len(tokenized_data)
    freqs = {root: count/total_count for root, count in roots_count.items()}
    p_drop = {root: 1 - np.sqrt(threshold/freqs[root]) for root in roots_count}
    sampled_roots = [root for root in tokenized_data if random.random() < (1 - p_drop[root])]
    return sampled_roots 

sampled_roots = subsample(tokenized_data)
print(len(tokenized_data))
print(len(sampled_roots))
# Out:
# 2868653
# 122188

# %% [markdown]
# ## Make Batches

# %%
def get_targets(roots, idx, window_size=8): 
    """
    Here we set window_size = 5 and select randomly a number N in the range (1:N)
    and then use N roots to current root and currnent + N roots in the future... reference roots as "words"
    :param roots: batch of sampled tokenized roots 
    :param idx: batch index 
    :param window_size: skip-gram window size -- HYPERPARAMETER 
    
    """
    N = np.random.randint(1, window_size + 1)
    start = idx - N if (idx - N) > 0 else 0 
    stop = idx + N
    targets = set(roots[start:idx] + roots[idx+1:stop+1])
    return list(targets)

# %%
def generate_batchs(roots, batch_size, window_size=8): 
    n_batches = len(roots)//batch_size 
    
    # make sure to select full batches 
    roots = roots[:n_batches * batch_size]
    
    for idx in range(0, len(roots), batch_size): 
        i, j = [], []
        batch = roots[idx:idx+batch_size]
        for ii in range(len(batch)): 
            batch_i = batch[ii]
            batch_j = get_targets(batch, ii, window_size)
            i.extend([batch_i] * len(batch_j))
            j.extend(batch_j)
        yield i, j

# %%
def print_sample_batch(tokenized_data=sampled_roots[:100]): 
    for ii in range(1): 
        batches = generate_batchs(tokenized_data, 10, 10)
        for i, j in batches: 
            print("epoch {}".format(ii))
            print("length of roots: {}".format(len(i)))
            print("roots: ")
            print(i)
            print("---------------")
            print("labels: ")
            print(np.array(j)[:, None])
            print(" ")
print_sample_batch()
# Out:
# epoch 0
# length of roots: 61
# roots:
# [434, 434, 434, 434, 434, 62, 62, 62, 421, 421, 421, 421, 421, 421, 421, 421, 400, 400, 705, 705, 705, 705, 705, 705, 705, 705, 705, 104, 104, 104, 104, 104, 104, 104, 104, 104, 288, 288, 283, 283, 283, 283, 283, 283, 283, 283, 283, 281, 281, 281, 281, 281, 281, 599, 599, 599, 599, 599, 599, 599, 599]
# ---------------
# labels:
# [[400]
#  [705]
#  [104]
#  [421]
#  [ 62]
#  [400]
#  [434]
#  [421]
#  [288]
#  [705]
#  [104]
#  [400]
#  [434]
#  [281]
#  [283]
#  [ 62]
#  [705]
#  [421]
#  [288]
#  [421]
#  [104]
#  [400]
#  [434]
#  [599]
#  [281]
#  [283]
#  [ 62]
#  [288]
#  [705]
#  [421]
#  [400]
#  [434]
#  [599]
#  [281]
#  [283]
#  [ 62]
#  [104]
#  [283]
#  [288]
#  [705]
#  [421]
#  [104]
#  [400]
#  [434]
#  [599]
#  [281]
#  [ 62]
#  [288]
#  [705]
#  [104]
#  [400]
#  [599]
#  [283]
#  [288]
#  [705]
#  [421]
#  [104]
#  [400]
#  [281]
#  [283]
#  [ 62]]
#
# epoch 0
# length of roots: 41
# roots:
# [794, 794, 193, 193, 802, 802, 233, 233, 233, 233, 483, 483, 483, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 705, 491, 491, 406, 406, 406, 406, 406, 406]
# ---------------
# labels:
# [[193]
#  [802]
#  [794]
#  [802]
#  [193]
#  [233]
#  [193]
#  [802]
#  [483]
#  [705]
#  [233]
#  [802]
#  [705]
#  [705]
#  [193]
#  [483]
#  [802]
#  [233]
#  [491]
#  [406]
#  [794]
#  [193]
#  [802]
#  [483]
#  [705]
#  [233]
#  [491]
#  [406]
#  [233]
#  [483]
#  [705]
#  [406]
#  [491]
#  [705]
#  [406]
#  [193]
#  [802]
#  [483]
#  [705]
#  [233]
#  [491]]
#
# epoch 0
# length of roots: 68
# roots:
# [406, 406, 406, 406, 406, 406, 406, 406, 406, 373, 373, 373, 373, 373, 373, 373, 373, 406, 406, 406, 406, 406, 734, 734, 734, 734, 734, 734, 764, 764, 764, 764, 764, 764, 168, 168, 168, 168, 168, 168, 168, 168, 49, 49, 49, 49, 49, 49, 49, 49, 310, 310, 310, 310, 310, 310, 310, 310, 199, 199, 199, 199, 199, 434, 434, 434, 434, 434]
# ---------------
# labels:
# [[199]
#  [168]
#  [ 49]
#  [434]
#  [373]
#  [406]
#  [310]
#  [764]
#  [734]
#  [199]
#  [168]
#  [ 49]
#  [434]
#  [406]
#  [310]
#  [764]
#  [734]
#  [168]
#  [734]
#  [764]
#  [373]
#  [406]
#  [168]
#  [ 49]
#  [373]
#  [406]
#  [310]
#  [764]
#  [168]
#  [ 49]
#  [373]
#  [406]
#  [310]
#  [734]
#  [199]
#  [ 49]
#  [434]
#  [373]
#  [310]
#  [406]
#  [764]
#  [734]
#  [199]
#  [168]
#  [434]
#  [373]
#  [310]
#  [406]
#  [764]
#  [734]
#  [199]
#  [168]
#  [ 49]
#  [434]
#  [373]
#  [406]
#  [764]
#  [734]
#  [168]
#  [ 49]
#  [434]
#  [764]
#  [310]
#  [168]
#  [ 49]
#  [764]
#  [310]
#  [199]]
#
# epoch 0
# length of roots: 58
# roots:
# [29, 29, 29, 602, 602, 602, 602, 602, 602, 602, 602, 602, 199, 199, 440, 440, 440, 440, 848, 848, 848, 848, 476, 476, 476, 476, 476, 476, 476, 476, 476, 831, 831, 831, 831, 831, 831, 831, 831, 772, 772, 772, 772, 772, 772, 772, 772, 772, 371, 371, 371, 371, 371, 371, 371, 371, 371, 549]
# ---------------
# labels:
# [[440]
#  [602]
#  [199]
#  [772]
#  [549]
#  [199]
#  [848]
#  [371]
#  [440]
#  [476]
#  [ 29]
#  [831]
#  [440]
#  [602]
#  [848]
#  [602]
#  [476]
#  [199]
#  [440]
#  [476]
#  [831]
#  [199]
#  [772]
#  [549]
#  [199]
#  [848]
#  [371]
#  [440]
#  [602]
#  [ 29]
#  [831]
#  [772]
#  [549]
#  [199]
#  [848]
#  [371]
#  [440]
#  [602]
#  [476]
#  [549]
#  [199]
#  [848]
#  [371]
#  [440]
#  [602]
#  [476]
#  [ 29]
#  [831]
#  [772]
#  [549]
#  [199]
#  [848]
#  [440]
#  [602]
#  [476]
#  [ 29]
#  [831]
#  [371]]
#
# epoch 0
# length of roots: 33
# roots:
# [11, 11, 11, 11, 11, 355, 355, 355, 549, 549, 549, 549, 549, 549, 549, 549, 549, 549, 549, 549, 254, 254, 254, 254, 254, 11, 11, 642, 642, 408, 408, 408, 408]
# ---------------
# labels:
# [[ 11]
#  [642]
#  [355]
#  [549]
#  [254]
#  [ 11]
#  [549]
#  [254]
#  [355]
#  [549]
#  [355]
#  [549]
#  [355]
#  [642]
#  [ 11]
#  [549]
#  [254]
#  [ 11]
#  [549]
#  [254]
#  [355]
#  [408]
#  [642]
#  [ 11]
#  [549]
#  [642]
#  [254]
#  [408]
#  [ 11]
#  [642]
#  [ 11]
#  [549]
#  [254]]
#
# epoch 0
# length of roots: 66
# roots:
# [669, 669, 669, 669, 551, 551, 551, 551, 551, 551, 551, 551, 567, 567, 567, 567, 567, 567, 567, 567, 288, 288, 288, 288, 288, 288, 288, 288, 848, 848, 848, 848, 848, 848, 848, 848, 848, 848, 848, 319, 319, 319, 319, 319, 319, 319, 319, 316, 316, 316, 316, 316, 316, 316, 316, 507, 507, 507, 507, 507, 507, 507, 880, 880, 880, 880]
# ---------------
# labels:
# [[288]
#  [848]
#  [567]
#  [551]
#  [288]
#  [848]
#  [880]
#  [567]
#  [507]
#  [316]
#  [669]
#  [319]
#  [288]
#  [551]
#  [848]
#  [880]
#  [507]
#  [316]
#  [669]
#  [319]
#  [551]
#  [848]
#  [880]
#  [567]
#  [507]
#  [316]
#  [669]
#  [319]
#  [288]
#  [551]
#  [848]
#  [880]
#  [567]
#  [507]
#  [316]
#  [669]
#  [319]
#  [848]
#  [319]
#  [288]
#  [551]
#  [848]
#  [880]
#  [567]
#  [507]
#  [316]
#  [669]
#  [288]
#  [551]
#  [848]
#  [880]
#  [567]
#  [507]
#  [669]
#  [319]
#  [288]
#  [551]
#  [848]
#  [880]
#  [567]
#  [316]
#  [319]
#  [848]
#  [507]
#  [316]
#  [319]]
#
# epoch 0
# length of roots: 60
# roots:
# [320, 320, 567, 567, 567, 567, 567, 567, 567, 567, 567, 377, 377, 377, 377, 103, 103, 103, 103, 103, 103, 103, 103, 103, 769, 769, 769, 769, 314, 314, 314, 314, 314, 314, 314, 314, 28, 28, 28, 28, 28, 28, 28, 28, 28, 566, 566, 566, 566, 566, 566, 855, 855, 855, 855, 788, 788, 788, 788, 788]
# ---------------
# labels:
# [[377]
#  [567]
#  [320]
#  [769]
#  [103]
#  [788]
#  [566]
#  [855]
#  [377]
#  [314]
#  [ 28]
#  [320]
#  [769]
#  [103]
#  [567]
#  [320]
#  [769]
#  [855]
#  [788]
#  [566]
#  [567]
#  [377]
#  [314]
#  [ 28]
#  [377]
#  [314]
#  [ 28]
#  [103]
#  [769]
#  [103]
#  [855]
#  [788]
#  [566]
#  [567]
#  [377]
#  [ 28]
#  [320]
#  [769]
#  [103]
#  [855]
#  [788]
#  [566]
#  [567]
#  [377]
#  [314]
#  [769]
#  [103]
#  [788]
#  [855]
#  [314]
#  [ 28]
#  [314]
#  [ 28]
#  [788]
#  [566]
#  [769]
#  [314]
#  [ 28]
#  [566]
#  [855]]
#
# epoch 0
# length of roots: 53
# roots:
# [839, 193, 193, 193, 193, 193, 193, 193, 193, 386, 386, 386, 386, 386, 618, 618, 618, 618, 618, 618, 440, 440, 440, 440, 551, 551, 551, 551, 424, 424, 424, 424, 424, 424, 424, 507, 507, 507, 507, 507, 507, 507, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831, 831]
# ---------------
# labels:
# [[193]
#  [386]
#  [551]
#  [424]
#  [839]
#  [618]
#  [440]
#  [507]
#  [831]
#  [440]
#  [193]
#  [618]
#  [551]
#  [839]
#  [193]
#  [386]
#  [551]
#  [424]
#  [839]
#  [440]
#  [424]
#  [386]
#  [618]
#  [551]
#  [440]
#  [618]
#  [507]
#  [424]
#  [193]
#  [386]
#  [551]
#  [618]
#  [440]
#  [507]
#  [831]
#  [193]
#  [386]
#  [551]
#  [424]
#  [618]
#  [440]
#  [831]
#  [193]
#  [386]
#  [551]
#  [839]
#  [424]
#  [618]
#  [440]
#  [507]
#  [831]
#  [507]
#  [831]]
#
# epoch 0
# length of roots: 55
# roots:
# [311, 311, 311, 763, 763, 763, 763, 763, 763, 763, 763, 763, 30, 30, 30, 30, 30, 30, 30, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 62, 30, 30, 30, 30, 30, 30, 30, 623, 623, 623, 623, 623, 623, 291, 291, 291, 291, 291, 157, 157, 157, 157]
# ---------------
# labels:
# [[ 62]
#  [763]
#  [ 30]
#  [ 62]
#  [763]
#  [623]
#  [ 30]
#  [311]
#  [ 62]
#  [763]
#  [ 30]
#  [311]
#  [291]
#  [623]
#  [311]
#  [ 62]
#  [763]
#  [157]
#  [ 30]
#  [291]
#  [623]
#  [157]
#  [ 30]
#  [763]
#  [311]
#  [ 62]
#  [291]
#  [623]
#  [157]
#  [ 30]
#  [763]
#  [311]
#  [ 62]
#  [291]
#  [623]
#  [157]
#  [ 30]
#  [763]
#  [311]
#  [ 62]
#  [291]
#  [311]
#  [ 30]
#  [763]
#  [157]
#  [ 62]
#  [ 62]
#  [763]
#  [157]
#  [ 30]
#  [623]
#  [ 62]
#  [291]
#  [ 30]
#  [623]]
#
# epoch 0
# length of roots: 54
# roots:
# [545, 545, 545, 545, 31, 31, 31, 31, 31, 698, 698, 698, 698, 698, 698, 576, 576, 576, 576, 576, 483, 483, 483, 483, 483, 483, 31, 31, 31, 31, 31, 31, 31, 476, 476, 476, 476, 476, 476, 527, 527, 527, 527, 527, 545, 545, 545, 31, 31, 31, 31, 31, 31, 31]
# ---------------
# labels:
# [[576]
#  [698]
#  [483]
#  [ 31]
#  [576]
#  [545]
#  [698]
#  [483]
#  [ 31]
#  [576]
#  [545]
#  [483]
#  [527]
#  [476]
#  [ 31]
#  [545]
#  [698]
#  [483]
#  [476]
#  [ 31]
#  [576]
#  [545]
#  [527]
#  [698]
#  [476]
#  [ 31]
#  [576]
#  [545]
#  [483]
#  [527]
#  [698]
#  [476]
#  [ 31]
#  [576]
#  [545]
#  [483]
#  [527]
#  [698]
#  [ 31]
#  [576]
#  [545]
#  [483]
#  [476]
#  [ 31]
#  [476]
#  [ 31]
#  [527]
#  [576]
#  [545]
#  [483]
#  [527]
#  [698]
#  [476]
#  [ 31]]

# %% [markdown]
# ### Hyperparameters

# %%
learning_rate = 0.001
vocab_size = len(dic)   ##881 vocabulary size 
rate = 0.4 # dropout_rate = 1 - rate 
embedding_size = 300  # number of embedding features 
num_sampled = 64 # number of negative examples to sample
epochs = 100
batch_size = 128
window_size = 10

#Select random sample of most frequent words for model validation 
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.

print("vocabulary size ", vocab_size)
# Out:
# vocabulary size  881

# %% [markdown]
# ## Build Network
# Input words are passed in as one-hot encoded vectors, which feed into a single hidden linear layer.
# The output of the embedding matrix of this network will then be fed into a CNN for prediction later on.

# %% [markdown]
# ### Initialize Graph
# We have varying input sizes so we set the dimenision to **None** and the second dimension of the
# labels to **None** as well.

# %%
train_graph = tf.Graph()
with train_graph.as_default(): 
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ### Embedding
# Here the embedding matrix has the dimensions --> (tokenized_data X hidden_layers == embedding_size)

# %%
with train_graph.as_default(): 
    embedding = tf.Variable(tf.random_uniform((vocab_size, embedding_size), -1, 1))
    embedding = tf.nn.dropout(embedding, keep_prob=1 - rate, noise_shape=[vocab_size, 1])
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ### Negative Sampling

# %%
with train_graph.as_default(): 
    nce_weights = tf.Variable(tf.truncated_normal([vocab_size, embedding_size], stddev=1.0/math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocab_size]))
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights, 
            biases=nce_biases, 
            labels=labels, 
            inputs=embed, 
            num_sampled=num_sampled, 
            num_classes=vocab_size
        )
    )
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %% [markdown]
# ## Validation
# pick most common and least common roots

# %%
with train_graph.as_default(): 
    ## From Thusan Ganegedara's implementation 
    
    # pick top 8 samples from (0, 100) and (600, 700) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, random.sample(range(100, 600+valid_window), valid_size//2))
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # use cosine distance 
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding/norm 
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# if the checkpoints directory does not exist then make it 
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %%
with train_graph.as_default(): 
    saver = tf.train.Saver()
with tf.Session(graph=train_graph) as sess:
    step = 1
    avg_loss = 0
    sess.run(tf.global_variables_initializer())
    for ii in range(1, epochs+1): 
        batches = generate_batchs(sampled_roots, batch_size, window_size)
        start = time.time()
        for i, j in batches: 
            feed = {inputs: i, labels: np.array(j)[:, None]}
            train_loss, _ = sess.run([loss, optimizer], feed_dict=feed)
            avg_loss += train_loss 
            if step % 100 == 0: 
                # Mat Leonard implementation 
                end = time.time()
                print("Epoch {}/{}".format(ii, epochs), 
                     "Iteration: {}".format(step), 
                     "Avg. Training loss: {:.4f}".format(avg_loss/100), 
                     "{:.4f} sec/batch".format((end - start)/100))
                avg_loss = 0
                start = time.time()
            if step % 10000 == 0: 
                sim = similarity.eval()
                for idx in range(valid_size): 
                    valid_word = rev_dic[valid_examples[idx]]
                    top_k = 8
                    nearest = (-sim[idx, :]).argsort()[1:top_k+1]
                    log = "Nearest to %s:" % valid_word 
                    for k in range(top_k):
                        close_word = rev_dic[nearest[k]]
                        log = "%s %s" % (log, close_word)
                    print(log)
                    print("\n")
            step += 1
    save_path = saver.save(sess, "checkpoints/word_embeddings.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/100 Iteration: 100 Avg. Training loss: 135.0564 0.0135 sec/batch
# Epoch 1/100 Iteration: 200 Avg. Training loss: 120.5786 0.0056 sec/batch
# Epoch 1/100 Iteration: 300 Avg. Training loss: 101.0337 0.0057 sec/batch
# Epoch 1/100 Iteration: 400 Avg. Training loss: 85.7180 0.0057 sec/batch
# Epoch 1/100 Iteration: 500 Avg. Training loss: 75.2623 0.0057 sec/batch
# Epoch 1/100 Iteration: 600 Avg. Training loss: 66.9344 0.0057 sec/batch
# Epoch 1/100 Iteration: 700 Avg. Training loss: 58.5197 0.0057 sec/batch
# Epoch 1/100 Iteration: 800 Avg. Training loss: 58.6486 0.0057 sec/batch
# Epoch 1/100 Iteration: 900 Avg. Training loss: 56.3798 0.0057 sec/batch
# Epoch 2/100 Iteration: 1000 Avg. Training loss: 55.7231 0.0026 sec/batch
# Epoch 2/100 Iteration: 1100 Avg. Training loss: 53.4600 0.0056 sec/batch
# Epoch 2/100 Iteration: 1200 Avg. Training loss: 52.9886 0.0059 sec/batch
# Epoch 2/100 Iteration: 1300 Avg. Training loss: 51.5393 0.0062 sec/batch
# Epoch 2/100 Iteration: 1400 Avg. Training loss: 52.7958 0.0057 sec/batch
# Epoch 2/100 Iteration: 1500 Avg. Training loss: 52.0391 0.0056 sec/batch
# Epoch 2/100 Iteration: 1600 Avg. Training loss: 49.1139 0.0057 sec/batch
# Epoch 2/100 Iteration: 1700 Avg. Training loss: 49.6441 0.0058 sec/batch
# Epoch 2/100 Iteration: 1800 Avg. Training loss: 49.2342 0.0057 sec/batch
# Epoch 2/100 Iteration: 1900 Avg. Training loss: 47.1465 0.0055 sec/batch
# Epoch 3/100 Iteration: 2000 Avg. Training loss: 48.0372 0.0052 sec/batch
# Epoch 3/100 Iteration: 2100 Avg. Training loss: 45.2620 0.0055 sec/batch
# Epoch 3/100 Iteration: 2200 Avg. Training loss: 46.4653 0.0058 sec/batch
# Epoch 3/100 Iteration: 2300 Avg. Training loss: 45.6455 0.0057 sec/batch
# Epoch 3/100 Iteration: 2400 Avg. Training loss: 46.7848 0.0058 sec/batch
# Epoch 3/100 Iteration: 2500 Avg. Training loss: 43.2212 0.0057 sec/batch
# Epoch 3/100 Iteration: 2600 Avg. Training loss: 44.2012 0.0058 sec/batch
# Epoch 3/100 Iteration: 2700 Avg. Training loss: 44.0201 0.0058 sec/batch
# Epoch 3/100 Iteration: 2800 Avg. Training loss: 44.3731 0.0057 sec/batch
# Epoch 4/100 Iteration: 2900 Avg. Training loss: 42.2787 0.0021 sec/batch
# Epoch 4/100 Iteration: 3000 Avg. Training loss: 43.4037 0.0056 sec/batch
# Epoch 4/100 Iteration: 3100 Avg. Training loss: 41.7644 0.0057 sec/batch
# Epoch 4/100 Iteration: 3200 Avg. Training loss: 41.1216 0.0057 sec/batch
# Epoch 4/100 Iteration: 3300 Avg. Training loss: 43.2613 0.0058 sec/batch
# Epoch 4/100 Iteration: 3400 Avg. Training loss: 39.9393 0.0060 sec/batch
# Epoch 4/100 Iteration: 3500 Avg. Training loss: 40.2485 0.0057 sec/batch
# Epoch 4/100 Iteration: 3600 Avg. Training loss: 39.2618 0.0057 sec/batch
# Epoch 4/100 Iteration: 3700 Avg. Training loss: 39.6716 0.0056 sec/batch
# Epoch 4/100 Iteration: 3800 Avg. Training loss: 38.8730 0.0055 sec/batch
# Epoch 5/100 Iteration: 3900 Avg. Training loss: 39.5184 0.0048 sec/batch
# Epoch 5/100 Iteration: 4000 Avg. Training loss: 38.3184 0.0056 sec/batch
# Epoch 5/100 Iteration: 4100 Avg. Training loss: 37.6122 0.0058 sec/batch
# Epoch 5/100 Iteration: 4200 Avg. Training loss: 37.6291 0.0059 sec/batch
# Epoch 5/100 Iteration: 4300 Avg. Training loss: 36.7521 0.0058 sec/batch
# Epoch 5/100 Iteration: 4400 Avg. Training loss: 38.4275 0.0057 sec/batch
# Epoch 5/100 Iteration: 4500 Avg. Training loss: 37.5186 0.0057 sec/batch
# Epoch 5/100 Iteration: 4600 Avg. Training loss: 36.5246 0.0058 sec/batch
# Epoch 5/100 Iteration: 4700 Avg. Training loss: 35.4581 0.0055 sec/batch
# Epoch 6/100 Iteration: 4800 Avg. Training loss: 35.1642 0.0017 sec/batch
# Epoch 6/100 Iteration: 4900 Avg. Training loss: 34.9286 0.0056 sec/batch
# Epoch 6/100 Iteration: 5000 Avg. Training loss: 35.0242 0.0058 sec/batch
# Epoch 6/100 Iteration: 5100 Avg. Training loss: 35.7729 0.0057 sec/batch
# Epoch 6/100 Iteration: 5200 Avg. Training loss: 33.1218 0.0057 sec/batch
# Epoch 6/100 Iteration: 5300 Avg. Training loss: 32.8405 0.0058 sec/batch
# Epoch 6/100 Iteration: 5400 Avg. Training loss: 33.4566 0.0056 sec/batch
# Epoch 6/100 Iteration: 5500 Avg. Training loss: 31.8802 0.0056 sec/batch
# Epoch 6/100 Iteration: 5600 Avg. Training loss: 32.9371 0.0057 sec/batch
# Epoch 6/100 Iteration: 5700 Avg. Training loss: 33.1529 0.0057 sec/batch
# Epoch 7/100 Iteration: 5800 Avg. Training loss: 31.5803 0.0043 sec/batch
# Epoch 7/100 Iteration: 5900 Avg. Training loss: 30.8458 0.0057 sec/batch
# Epoch 7/100 Iteration: 6000 Avg. Training loss: 31.5738 0.0057 sec/batch
# Epoch 7/100 Iteration: 6100 Avg. Training loss: 31.4651 0.0057 sec/batch
# Epoch 7/100 Iteration: 6200 Avg. Training loss: 31.1374 0.0057 sec/batch
# Epoch 7/100 Iteration: 6300 Avg. Training loss: 31.3015 0.0057 sec/batch
# Epoch 7/100 Iteration: 6400 Avg. Training loss: 30.9880 0.0056 sec/batch
# Epoch 7/100 Iteration: 6500 Avg. Training loss: 31.4320 0.0056 sec/batch
# Epoch 7/100 Iteration: 6600 Avg. Training loss: 28.5859 0.0057 sec/batch
# Epoch 8/100 Iteration: 6700 Avg. Training loss: 29.4404 0.0013 sec/batch
# Epoch 8/100 Iteration: 6800 Avg. Training loss: 28.0968 0.0060 sec/batch
# Epoch 8/100 Iteration: 6900 Avg. Training loss: 29.3745 0.0058 sec/batch
# Epoch 8/100 Iteration: 7000 Avg. Training loss: 27.7966 0.0056 sec/batch
# Epoch 8/100 Iteration: 7100 Avg. Training loss: 28.8941 0.0060 sec/batch
# Epoch 8/100 Iteration: 7200 Avg. Training loss: 28.4515 0.0061 sec/batch
# Epoch 8/100 Iteration: 7300 Avg. Training loss: 27.5788 0.0058 sec/batch
# Epoch 8/100 Iteration: 7400 Avg. Training loss: 27.3493 0.0058 sec/batch
# Epoch 8/100 Iteration: 7500 Avg. Training loss: 27.3161 0.0059 sec/batch
# Epoch 8/100 Iteration: 7600 Avg. Training loss: 27.6779 0.0058 sec/batch
# Epoch 9/100 Iteration: 7700 Avg. Training loss: 27.1870 0.0039 sec/batch
# Epoch 9/100 Iteration: 7800 Avg. Training loss: 25.9528 0.0058 sec/batch
# Epoch 9/100 Iteration: 7900 Avg. Training loss: 26.7794 0.0058 sec/batch
# Epoch 9/100 Iteration: 8000 Avg. Training loss: 26.0589 0.0062 sec/batch
# Epoch 9/100 Iteration: 8100 Avg. Training loss: 25.8945 0.0063 sec/batch
# Epoch 9/100 Iteration: 8200 Avg. Training loss: 25.6288 0.0059 sec/batch
# Epoch 9/100 Iteration: 8300 Avg. Training loss: 25.6111 0.0059 sec/batch
# Epoch 9/100 Iteration: 8400 Avg. Training loss: 25.9169 0.0060 sec/batch
# Epoch 9/100 Iteration: 8500 Avg. Training loss: 25.4331 0.0065 sec/batch
# Epoch 10/100 Iteration: 8600 Avg. Training loss: 25.8385 0.0010 sec/batch
# Epoch 10/100 Iteration: 8700 Avg. Training loss: 25.3409 0.0062 sec/batch
# Epoch 10/100 Iteration: 8800 Avg. Training loss: 23.7848 0.0059 sec/batch
# Epoch 10/100 Iteration: 8900 Avg. Training loss: 24.1710 0.0056 sec/batch
# Epoch 10/100 Iteration: 9000 Avg. Training loss: 24.2411 0.0059 sec/batch
# Epoch 10/100 Iteration: 9100 Avg. Training loss: 22.7470 0.0060 sec/batch
# Epoch 10/100 Iteration: 9200 Avg. Training loss: 24.0820 0.0055 sec/batch
# Epoch 10/100 Iteration: 9300 Avg. Training loss: 24.0179 0.0055 sec/batch
# Epoch 10/100 Iteration: 9400 Avg. Training loss: 23.3521 0.0057 sec/batch
# Epoch 10/100 Iteration: 9500 Avg. Training loss: 23.3491 0.0057 sec/batch
# Epoch 11/100 Iteration: 9600 Avg. Training loss: 23.0213 0.0040 sec/batch
# Epoch 11/100 Iteration: 9700 Avg. Training loss: 22.7535 0.0061 sec/batch
# Epoch 11/100 Iteration: 9800 Avg. Training loss: 22.7650 0.0057 sec/batch
# Epoch 11/100 Iteration: 9900 Avg. Training loss: 22.1344 0.0056 sec/batch
# Epoch 11/100 Iteration: 10000 Avg. Training loss: 21.7734 0.0056 sec/batch
# Nearest to INS_LambdaExpression_ReturnStatement: DEL_PrimitiveType INS_MethodInvocation_MethodInvocation INS_Initializer_AnonymousClassDeclaration INS_Block_DoStatement INS_PrefixExpression_EnumConstantDeclaration INS_EmptyStatement_Block INS_SimpleName_SynchronizedStatement INS_SimpleType_ArrayType
#
#
# Nearest to INS_ArrayCreation_ConditionalExpression: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to MOVE_Javadoc: INS_FieldAccess_ConditionalExpression INS_ConditionalExpression_ThrowStatement INS_PrefixExpression_AnnotationTypeMemberDeclaration INS_InfixExpression_ArrayInitializer INS_TextElement_change INS_BooleanLiteral_AssertStatement INS_SingleVariableDeclaration_CatchClause INS_MethodInvocation_SuperConstructorInvocation
#
#
# Nearest to INS_InstanceofExpression_WhileStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_SwitchStatement_SwitchStatement: INS_SimpleType_TypeLiteral INS_ParenthesizedExpression_IfStatement INS_PrefixExpression_MethodInvocation INS_SimpleName_TagElement INS_ForStatement_SwitchStatement INS_InfixExpression_ArrayInitializer DEL_ReturnStatement DEL_EnumDeclaration
#
#
# Nearest to INS_SimpleType_TypeParameter: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_MethodInvocation_ConditionalExpression: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to DEL_TextElement:: INS_SimpleName_SynchronizedStatement INS_ArrayInitializer_SingleMemberAnnotation INS_SimpleName_TagElement MOVE_LambdaExpression INS_QualifiedName_SuperConstructorInvocation INS_MethodInvocation_ReturnStatement INS_QualifiedName_SwitchStatement MOVE_TypeParameter
#
#
# Nearest to INS_TextElement_memory_starts: INS_AnnotationTypeDeclaration_AnnotationTypeDeclaration INS_CastExpression_EnhancedForStatement INS_Javadoc_Initializer INS_BooleanLiteral_ClassInstanceCreation INS_PrefixExpression_VariableDeclarationFragment INS_SuperMethodInvocation_CastExpression INS_LambdaExpression_VariableDeclarationFragment DEL_EnumDeclaration
#
#
# Nearest to DEL_ClassInstanceCreation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_SimpleName_SingleMemberAnnotation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_Block_CatchClause: INS_ParenthesizedExpression_FieldAccess INS_StringLiteral_EnumConstantDeclaration INS_InfixExpression_ConditionalExpression INS_ConditionalExpression_VariableDeclarationFragment INS_FieldAccess_SuperMethodInvocation INS_TryStatement_Block INS_ThisExpression_MethodInvocation INS_FieldAccess_Assignment
#
#
# Nearest to MOVE_SuperConstructorInvocation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_CastExpression_ArrayCreation: INS_EnhancedForStatement_SwitchStatement DEL_CharacterLiteral DEL_Initializer INS_FieldAccess_PostfixExpression INS_SimpleName_InstanceofExpression INS_TextElement:_TextElement: INS_ClassInstanceCreation_ReturnStatement INS_ArrayAccess_InfixExpression
#
#
# Nearest to INS_QualifiedName_ReturnStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_TextElement_TagElement: MOVE_MemberValuePair INS_Modifier_EnumDeclaration INS_TextElement:_do_so INS_SimpleName_SwitchCase INS_NumberLiteral_ReturnStatement INS_VariableDeclarationStatement_SwitchStatement MOVE_FieldDeclaration INS_NumberLiteral_ArrayAccess
# Epoch 11/100 Iteration: 10100 Avg. Training loss: 22.3461 0.0059 sec/batch
# Epoch 11/100 Iteration: 10200 Avg. Training loss: 20.7530 0.0058 sec/batch
# Epoch 11/100 Iteration: 10300 Avg. Training loss: 20.9431 0.0056 sec/batch
# Epoch 11/100 Iteration: 10400 Avg. Training loss: 20.9601 0.0056 sec/batch
# Epoch 12/100 Iteration: 10500 Avg. Training loss: 21.0523 0.0003 sec/batch
# Epoch 12/100 Iteration: 10600 Avg. Training loss: 21.9029 0.0054 sec/batch
# Epoch 12/100 Iteration: 10700 Avg. Training loss: 21.0621 0.0056 sec/batch
# Epoch 12/100 Iteration: 10800 Avg. Training loss: 21.6120 0.0059 sec/batch
# Epoch 12/100 Iteration: 10900 Avg. Training loss: 21.0508 0.0058 sec/batch
# Epoch 12/100 Iteration: 11000 Avg. Training loss: 20.5494 0.0058 sec/batch
# Epoch 12/100 Iteration: 11100 Avg. Training loss: 20.3937 0.0057 sec/batch
# Epoch 12/100 Iteration: 11200 Avg. Training loss: 19.3147 0.0061 sec/batch
# Epoch 12/100 Iteration: 11300 Avg. Training loss: 19.4225 0.0058 sec/batch
# Epoch 12/100 Iteration: 11400 Avg. Training loss: 20.0572 0.0058 sec/batch
# Epoch 13/100 Iteration: 11500 Avg. Training loss: 20.0008 0.0031 sec/batch
# Epoch 13/100 Iteration: 11600 Avg. Training loss: 19.3707 0.0057 sec/batch
# Epoch 13/100 Iteration: 11700 Avg. Training loss: 19.1001 0.0058 sec/batch
# Epoch 13/100 Iteration: 11800 Avg. Training loss: 18.8434 0.0061 sec/batch
# Epoch 13/100 Iteration: 11900 Avg. Training loss: 18.4770 0.0059 sec/batch
# Epoch 13/100 Iteration: 12000 Avg. Training loss: 19.4615 0.0057 sec/batch
# Epoch 13/100 Iteration: 12100 Avg. Training loss: 19.5200 0.0056 sec/batch
# Epoch 13/100 Iteration: 12200 Avg. Training loss: 19.1295 0.0058 sec/batch
# Epoch 13/100 Iteration: 12300 Avg. Training loss: 19.1759 0.0059 sec/batch
# Epoch 13/100 Iteration: 12400 Avg. Training loss: 18.5106 0.0061 sec/batch
# Epoch 14/100 Iteration: 12500 Avg. Training loss: 17.6845 0.0055 sec/batch
# Epoch 14/100 Iteration: 12600 Avg. Training loss: 18.0914 0.0055 sec/batch
# Epoch 14/100 Iteration: 12700 Avg. Training loss: 17.8786 0.0059 sec/batch
# Epoch 14/100 Iteration: 12800 Avg. Training loss: 17.8647 0.0056 sec/batch
# Epoch 14/100 Iteration: 12900 Avg. Training loss: 18.2093 0.0058 sec/batch
# Epoch 14/100 Iteration: 13000 Avg. Training loss: 18.1913 0.0055 sec/batch
# Epoch 14/100 Iteration: 13100 Avg. Training loss: 16.6401 0.0056 sec/batch
# Epoch 14/100 Iteration: 13200 Avg. Training loss: 17.9198 0.0055 sec/batch
# Epoch 14/100 Iteration: 13300 Avg. Training loss: 16.6851 0.0056 sec/batch
# Epoch 15/100 Iteration: 13400 Avg. Training loss: 16.4545 0.0027 sec/batch
# Epoch 15/100 Iteration: 13500 Avg. Training loss: 16.6438 0.0057 sec/batch
# Epoch 15/100 Iteration: 13600 Avg. Training loss: 17.0892 0.0057 sec/batch
# Epoch 15/100 Iteration: 13700 Avg. Training loss: 16.0516 0.0056 sec/batch
# Epoch 15/100 Iteration: 13800 Avg. Training loss: 16.5875 0.0058 sec/batch
# Epoch 15/100 Iteration: 13900 Avg. Training loss: 16.4581 0.0057 sec/batch
# Epoch 15/100 Iteration: 14000 Avg. Training loss: 16.9343 0.0056 sec/batch
# Epoch 15/100 Iteration: 14100 Avg. Training loss: 15.9145 0.0056 sec/batch
# Epoch 15/100 Iteration: 14200 Avg. Training loss: 16.3331 0.0056 sec/batch
# Epoch 15/100 Iteration: 14300 Avg. Training loss: 15.6967 0.0056 sec/batch
# Epoch 16/100 Iteration: 14400 Avg. Training loss: 16.0201 0.0051 sec/batch
# Epoch 16/100 Iteration: 14500 Avg. Training loss: 15.4219 0.0055 sec/batch
# Epoch 16/100 Iteration: 14600 Avg. Training loss: 15.8156 0.0056 sec/batch
# Epoch 16/100 Iteration: 14700 Avg. Training loss: 15.3237 0.0056 sec/batch
# Epoch 16/100 Iteration: 14800 Avg. Training loss: 15.1986 0.0055 sec/batch
# Epoch 16/100 Iteration: 14900 Avg. Training loss: 15.2203 0.0058 sec/batch
# Epoch 16/100 Iteration: 15000 Avg. Training loss: 15.6769 0.0057 sec/batch
# Epoch 16/100 Iteration: 15100 Avg. Training loss: 15.3738 0.0056 sec/batch
# Epoch 16/100 Iteration: 15200 Avg. Training loss: 14.4762 0.0056 sec/batch
# Epoch 17/100 Iteration: 15300 Avg. Training loss: 15.0252 0.0020 sec/batch
# Epoch 17/100 Iteration: 15400 Avg. Training loss: 14.6675 0.0058 sec/batch
# Epoch 17/100 Iteration: 15500 Avg. Training loss: 15.1055 0.0056 sec/batch
# Epoch 17/100 Iteration: 15600 Avg. Training loss: 13.8009 0.0056 sec/batch
# Epoch 17/100 Iteration: 15700 Avg. Training loss: 14.4425 0.0056 sec/batch
# Epoch 17/100 Iteration: 15800 Avg. Training loss: 13.5948 0.0056 sec/batch
# Epoch 17/100 Iteration: 15900 Avg. Training loss: 14.4240 0.0056 sec/batch
# Epoch 17/100 Iteration: 16000 Avg. Training loss: 14.2799 0.0060 sec/batch
# Epoch 17/100 Iteration: 16100 Avg. Training loss: 14.4122 0.0058 sec/batch
# Epoch 17/100 Iteration: 16200 Avg. Training loss: 13.6617 0.0055 sec/batch
# Epoch 18/100 Iteration: 16300 Avg. Training loss: 14.0090 0.0045 sec/batch
# Epoch 18/100 Iteration: 16400 Avg. Training loss: 13.1369 0.0058 sec/batch
# Epoch 18/100 Iteration: 16500 Avg. Training loss: 13.7220 0.0056 sec/batch
# Epoch 18/100 Iteration: 16600 Avg. Training loss: 13.6132 0.0056 sec/batch
# Epoch 18/100 Iteration: 16700 Avg. Training loss: 13.4861 0.0055 sec/batch
# Epoch 18/100 Iteration: 16800 Avg. Training loss: 13.1282 0.0056 sec/batch
# Epoch 18/100 Iteration: 16900 Avg. Training loss: 13.2660 0.0057 sec/batch
# Epoch 18/100 Iteration: 17000 Avg. Training loss: 13.1493 0.0058 sec/batch
# Epoch 18/100 Iteration: 17100 Avg. Training loss: 13.1828 0.0055 sec/batch
# Epoch 19/100 Iteration: 17200 Avg. Training loss: 13.1657 0.0016 sec/batch
# Epoch 19/100 Iteration: 17300 Avg. Training loss: 12.6241 0.0056 sec/batch
# Epoch 19/100 Iteration: 17400 Avg. Training loss: 12.6632 0.0059 sec/batch
# Epoch 19/100 Iteration: 17500 Avg. Training loss: 12.9516 0.0058 sec/batch
# Epoch 19/100 Iteration: 17600 Avg. Training loss: 12.5246 0.0058 sec/batch
# Epoch 19/100 Iteration: 17700 Avg. Training loss: 12.7534 0.0058 sec/batch
# Epoch 19/100 Iteration: 17800 Avg. Training loss: 12.8510 0.0058 sec/batch
# Epoch 19/100 Iteration: 17900 Avg. Training loss: 12.3069 0.0057 sec/batch
# Epoch 19/100 Iteration: 18000 Avg. Training loss: 11.9291 0.0057 sec/batch
# Epoch 19/100 Iteration: 18100 Avg. Training loss: 11.6896 0.0056 sec/batch
# Epoch 20/100 Iteration: 18200 Avg. Training loss: 11.7829 0.0043 sec/batch
# Epoch 20/100 Iteration: 18300 Avg. Training loss: 12.2709 0.0059 sec/batch
# Epoch 20/100 Iteration: 18400 Avg. Training loss: 11.7825 0.0060 sec/batch
# Epoch 20/100 Iteration: 18500 Avg. Training loss: 12.0811 0.0061 sec/batch
# Epoch 20/100 Iteration: 18600 Avg. Training loss: 11.7724 0.0062 sec/batch
# Epoch 20/100 Iteration: 18700 Avg. Training loss: 11.4156 0.0061 sec/batch
# Epoch 20/100 Iteration: 18800 Avg. Training loss: 11.7860 0.0059 sec/batch
# Epoch 20/100 Iteration: 18900 Avg. Training loss: 11.7764 0.0059 sec/batch
# Epoch 20/100 Iteration: 19000 Avg. Training loss: 11.3976 0.0059 sec/batch
# Epoch 21/100 Iteration: 19100 Avg. Training loss: 11.8486 0.0011 sec/batch
# Epoch 21/100 Iteration: 19200 Avg. Training loss: 10.9642 0.0055 sec/batch
# Epoch 21/100 Iteration: 19300 Avg. Training loss: 11.0218 0.0055 sec/batch
# Epoch 21/100 Iteration: 19400 Avg. Training loss: 11.4172 0.0056 sec/batch
# Epoch 21/100 Iteration: 19500 Avg. Training loss: 11.1443 0.0056 sec/batch
# Epoch 21/100 Iteration: 19600 Avg. Training loss: 10.6570 0.0055 sec/batch
# Epoch 21/100 Iteration: 19700 Avg. Training loss: 10.5949 0.0055 sec/batch
# Epoch 21/100 Iteration: 19800 Avg. Training loss: 10.5144 0.0055 sec/batch
# Epoch 21/100 Iteration: 19900 Avg. Training loss: 10.8302 0.0055 sec/batch
# Epoch 21/100 Iteration: 20000 Avg. Training loss: 10.9493 0.0056 sec/batch
# Nearest to INS_LambdaExpression_ReturnStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_ArrayCreation_ConditionalExpression: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to MOVE_Javadoc: INS_MethodRef_TagElement INS_ConditionalExpression_ThrowStatement INS_InfixExpression_ArrayInitializer INS_BooleanLiteral_ConditionalExpression INS_TextElement_change INS_PrefixExpression_AnnotationTypeMemberDeclaration INS_TextElement:_disk,_but_extremely_fast INS_NumberLiteral_ConditionalExpression
#
#
# Nearest to INS_InstanceofExpression_WhileStatement: INS_ClassInstanceCreation_EnhancedForStatement INS_InfixExpression_SuperConstructorInvocation INS_SingleMemberAnnotation_AnnotationTypeDeclaration INS_StringLiteral_ArrayInitializer INS_PrimitiveType_ArrayType INS_WhileStatement_SwitchStatement INS_InfixExpression_ParenthesizedExpression INS_MethodDeclaration_TypeDeclaration
#
#
# Nearest to INS_SwitchStatement_SwitchStatement: INS_SimpleType_TypeLiteral INS_ParenthesizedExpression_EnhancedForStatement INS_InfixExpression_ArrayInitializer INS_ClassInstanceCreation_ClassInstanceCreation INS_SimpleName_TagElement INS_ArrayType_MethodRefParameter INS_SimpleType_VariableDeclarationExpression INS_NumberLiteral_PrefixExpression
#
#
# Nearest to INS_SimpleType_TypeParameter: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_MethodInvocation_ConditionalExpression: DEL_AnnotationTypeMemberDeclaration INS_VariableDeclarationFragment_FieldDeclaration INS_Initializer_TypeDeclaration INS_SynchronizedStatement_Block INS_TextElement_run_the_compiler_in-process_in_Java,_you_should_look INS_ArrayCreation_Assignment INS_FieldAccess_SwitchStatement INS_Modifier_MethodDeclaration
#
#
# Nearest to DEL_TextElement:: INS_ArrayInitializer_SingleMemberAnnotation INS_SimpleName_TagElement INS_InfixExpression_ArrayAccess INS_InfixExpression_LambdaExpression INS_SimpleName_ClassInstanceCreation DEL_ForStatement MOVE_ArrayCreation INS_SimpleName:_CastExpression
#
#
# Nearest to INS_TextElement_memory_starts: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to DEL_ClassInstanceCreation: INS_ArrayType_SingleVariableDeclaration INS_StringLiteral_Assignment INS_ArrayCreation_SuperMethodInvocation INS_SuperMethodInvocation_ConditionalExpression INS_StringLiteral_MethodInvocation INS_SimpleName_NormalAnnotation INS_ClassInstanceCreation_ThrowStatement INS_Javadoc_EnumDeclaration
#
#
# Nearest to INS_SimpleName_SingleMemberAnnotation: INS_InstanceofExpression_Assignment INS_LambdaExpression_MethodInvocation INS_StringLiteral_AssertStatement INS_CreationReference_MethodInvocation INS_FieldAccess_SwitchStatement INS_QualifiedName_PostfixExpression DEL_BooleanLiteral INS_InfixExpression_SuperConstructorInvocation
#
#
# Nearest to INS_Block_CatchClause: INS_ParenthesizedExpression_MethodInvocation INS_SingleMemberAnnotation_VariableDeclarationStatement INS_InfixExpression_ConditionalExpression INS_StringLiteral_EnumConstantDeclaration INS_SimpleName_BreakStatement INS_BooleanLiteral_MemberValuePair INS_ClassInstanceCreation_ClassInstanceCreation INS_FieldAccess_Assignment
#
#
# Nearest to MOVE_SuperConstructorInvocation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_CastExpression_ArrayCreation: INS_EnhancedForStatement_SwitchStatement INS_ParameterizedType_ArrayType INS_FieldAccess_PostfixExpression INS_ArrayAccess_InfixExpression DEL_ForStatement INS_Modifier_FieldDeclaration INS_SimpleType_MethodInvocation INS_ReturnStatement_Block
#
#
# Nearest to INS_QualifiedName_ReturnStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_TextElement_TagElement: MOVE_MemberValuePair INS_TextElement:_do_so INS_NullLiteral_ReturnStatement INS_TypeDeclaration_AnnotationTypeDeclaration INS_SimpleName_SwitchCase INS_Assignment_ParenthesizedExpression DEL_MarkerAnnotation MOVE_ClassInstanceCreation
# Epoch 22/100 Iteration: 20100 Avg. Training loss: 10.4694 0.0037 sec/batch
# Epoch 22/100 Iteration: 20200 Avg. Training loss: 10.1591 0.0055 sec/batch
# Epoch 22/100 Iteration: 20300 Avg. Training loss: 10.6122 0.0055 sec/batch
# Epoch 22/100 Iteration: 20400 Avg. Training loss: 10.6021 0.0057 sec/batch
# Epoch 22/100 Iteration: 20500 Avg. Training loss: 10.3431 0.0055 sec/batch
# Epoch 22/100 Iteration: 20600 Avg. Training loss: 9.6995 0.0055 sec/batch
# Epoch 22/100 Iteration: 20700 Avg. Training loss: 10.6481 0.0056 sec/batch
# Epoch 22/100 Iteration: 20800 Avg. Training loss: 10.0186 0.0054 sec/batch
# Epoch 22/100 Iteration: 20900 Avg. Training loss: 9.9448 0.0055 sec/batch
# Epoch 23/100 Iteration: 21000 Avg. Training loss: 9.9308 0.0007 sec/batch
# Epoch 23/100 Iteration: 21100 Avg. Training loss: 10.5583 0.0056 sec/batch
# Epoch 23/100 Iteration: 21200 Avg. Training loss: 10.1053 0.0057 sec/batch
# Epoch 23/100 Iteration: 21300 Avg. Training loss: 9.6869 0.0056 sec/batch
# Epoch 23/100 Iteration: 21400 Avg. Training loss: 9.4455 0.0055 sec/batch
# Epoch 23/100 Iteration: 21500 Avg. Training loss: 9.6540 0.0056 sec/batch
# Epoch 23/100 Iteration: 21600 Avg. Training loss: 9.7009 0.0056 sec/batch
# Epoch 23/100 Iteration: 21700 Avg. Training loss: 9.6029 0.0059 sec/batch
# Epoch 23/100 Iteration: 21800 Avg. Training loss: 9.9636 0.0056 sec/batch
# Epoch 23/100 Iteration: 21900 Avg. Training loss: 9.3330 0.0055 sec/batch
# Epoch 24/100 Iteration: 22000 Avg. Training loss: 9.7685 0.0032 sec/batch
# Epoch 24/100 Iteration: 22100 Avg. Training loss: 9.2965 0.0057 sec/batch
# Epoch 24/100 Iteration: 22200 Avg. Training loss: 9.4318 0.0059 sec/batch
# Epoch 24/100 Iteration: 22300 Avg. Training loss: 9.4331 0.0056 sec/batch
# Epoch 24/100 Iteration: 22400 Avg. Training loss: 9.4564 0.0056 sec/batch
# Epoch 24/100 Iteration: 22500 Avg. Training loss: 9.5226 0.0056 sec/batch
# Epoch 24/100 Iteration: 22600 Avg. Training loss: 9.1961 0.0055 sec/batch
# Epoch 24/100 Iteration: 22700 Avg. Training loss: 9.0427 0.0056 sec/batch
# Epoch 24/100 Iteration: 22800 Avg. Training loss: 9.0599 0.0059 sec/batch
# Epoch 25/100 Iteration: 22900 Avg. Training loss: 8.8604 0.0002 sec/batch
# Epoch 25/100 Iteration: 23000 Avg. Training loss: 9.2289 0.0056 sec/batch
# Epoch 25/100 Iteration: 23100 Avg. Training loss: 9.1078 0.0056 sec/batch
# Epoch 25/100 Iteration: 23200 Avg. Training loss: 8.7407 0.0059 sec/batch
# Epoch 25/100 Iteration: 23300 Avg. Training loss: 8.6696 0.0057 sec/batch
# Epoch 25/100 Iteration: 23400 Avg. Training loss: 8.6009 0.0055 sec/batch
# Epoch 25/100 Iteration: 23500 Avg. Training loss: 8.1438 0.0055 sec/batch
# Epoch 25/100 Iteration: 23600 Avg. Training loss: 8.7718 0.0055 sec/batch
# Epoch 25/100 Iteration: 23700 Avg. Training loss: 8.6371 0.0056 sec/batch
# Epoch 25/100 Iteration: 23800 Avg. Training loss: 8.4289 0.0057 sec/batch
# Epoch 26/100 Iteration: 23900 Avg. Training loss: 8.2623 0.0028 sec/batch
# Epoch 26/100 Iteration: 24000 Avg. Training loss: 8.3879 0.0055 sec/batch
# Epoch 26/100 Iteration: 24100 Avg. Training loss: 8.4729 0.0055 sec/batch
# Epoch 26/100 Iteration: 24200 Avg. Training loss: 8.5850 0.0055 sec/batch
# Epoch 26/100 Iteration: 24300 Avg. Training loss: 8.2430 0.0057 sec/batch
# Epoch 26/100 Iteration: 24400 Avg. Training loss: 8.2966 0.0057 sec/batch
# Epoch 26/100 Iteration: 24500 Avg. Training loss: 7.5166 0.0057 sec/batch
# Epoch 26/100 Iteration: 24600 Avg. Training loss: 8.1635 0.0055 sec/batch
# Epoch 26/100 Iteration: 24700 Avg. Training loss: 8.4083 0.0056 sec/batch
# Epoch 26/100 Iteration: 24800 Avg. Training loss: 8.1500 0.0056 sec/batch
# Epoch 27/100 Iteration: 24900 Avg. Training loss: 7.9780 0.0054 sec/batch
# Epoch 27/100 Iteration: 25000 Avg. Training loss: 7.9790 0.0057 sec/batch
# Epoch 27/100 Iteration: 25100 Avg. Training loss: 7.9557 0.0056 sec/batch
# Epoch 27/100 Iteration: 25200 Avg. Training loss: 7.6965 0.0055 sec/batch
# Epoch 27/100 Iteration: 25300 Avg. Training loss: 7.8393 0.0055 sec/batch
# Epoch 27/100 Iteration: 25400 Avg. Training loss: 7.6166 0.0057 sec/batch
# Epoch 27/100 Iteration: 25500 Avg. Training loss: 7.8356 0.0059 sec/batch
# Epoch 27/100 Iteration: 25600 Avg. Training loss: 7.5477 0.0055 sec/batch
# Epoch 27/100 Iteration: 25700 Avg. Training loss: 7.3202 0.0054 sec/batch
# Epoch 28/100 Iteration: 25800 Avg. Training loss: 7.1767 0.0023 sec/batch
# Epoch 28/100 Iteration: 25900 Avg. Training loss: 7.5852 0.0055 sec/batch
# Epoch 28/100 Iteration: 26000 Avg. Training loss: 7.2215 0.0055 sec/batch
# Epoch 28/100 Iteration: 26100 Avg. Training loss: 7.2816 0.0056 sec/batch
# Epoch 28/100 Iteration: 26200 Avg. Training loss: 7.4710 0.0056 sec/batch
# Epoch 28/100 Iteration: 26300 Avg. Training loss: 7.3447 0.0058 sec/batch
# Epoch 28/100 Iteration: 26400 Avg. Training loss: 7.3401 0.0055 sec/batch
# Epoch 28/100 Iteration: 26500 Avg. Training loss: 7.2719 0.0056 sec/batch
# Epoch 28/100 Iteration: 26600 Avg. Training loss: 7.0879 0.0056 sec/batch
# Epoch 28/100 Iteration: 26700 Avg. Training loss: 7.2007 0.0058 sec/batch
# Epoch 29/100 Iteration: 26800 Avg. Training loss: 6.9444 0.0048 sec/batch
# Epoch 29/100 Iteration: 26900 Avg. Training loss: 7.1529 0.0056 sec/batch
# Epoch 29/100 Iteration: 27000 Avg. Training loss: 7.0213 0.0056 sec/batch
# Epoch 29/100 Iteration: 27100 Avg. Training loss: 7.0797 0.0056 sec/batch
# Epoch 29/100 Iteration: 27200 Avg. Training loss: 7.1395 0.0058 sec/batch
# Epoch 29/100 Iteration: 27300 Avg. Training loss: 7.0619 0.0056 sec/batch
# Epoch 29/100 Iteration: 27400 Avg. Training loss: 6.9223 0.0056 sec/batch
# Epoch 29/100 Iteration: 27500 Avg. Training loss: 6.9082 0.0057 sec/batch
# Epoch 29/100 Iteration: 27600 Avg. Training loss: 6.7775 0.0056 sec/batch
# Epoch 30/100 Iteration: 27700 Avg. Training loss: 7.1202 0.0020 sec/batch
# Epoch 30/100 Iteration: 27800 Avg. Training loss: 6.9761 0.0057 sec/batch
# Epoch 30/100 Iteration: 27900 Avg. Training loss: 6.7235 0.0057 sec/batch
# Epoch 30/100 Iteration: 28000 Avg. Training loss: 6.8094 0.0056 sec/batch
# Epoch 30/100 Iteration: 28100 Avg. Training loss: 6.7558 0.0058 sec/batch
# Epoch 30/100 Iteration: 28200 Avg. Training loss: 6.6498 0.0060 sec/batch
# Epoch 30/100 Iteration: 28300 Avg. Training loss: 6.6145 0.0059 sec/batch
# Epoch 30/100 Iteration: 28400 Avg. Training loss: 6.6421 0.0058 sec/batch
# Epoch 30/100 Iteration: 28500 Avg. Training loss: 6.6671 0.0058 sec/batch
# Epoch 30/100 Iteration: 28600 Avg. Training loss: 6.4672 0.0058 sec/batch
# Epoch 31/100 Iteration: 28700 Avg. Training loss: 6.5953 0.0046 sec/batch
# Epoch 31/100 Iteration: 28800 Avg. Training loss: 6.6324 0.0059 sec/batch
# Epoch 31/100 Iteration: 28900 Avg. Training loss: 6.2116 0.0058 sec/batch
# Epoch 31/100 Iteration: 29000 Avg. Training loss: 6.3544 0.0058 sec/batch
# Epoch 31/100 Iteration: 29100 Avg. Training loss: 6.2039 0.0060 sec/batch
# Epoch 31/100 Iteration: 29200 Avg. Training loss: 6.2485 0.0059 sec/batch
# Epoch 31/100 Iteration: 29300 Avg. Training loss: 6.3349 0.0061 sec/batch
# Epoch 31/100 Iteration: 29400 Avg. Training loss: 6.1531 0.0060 sec/batch
# Epoch 31/100 Iteration: 29500 Avg. Training loss: 6.1751 0.0060 sec/batch
# Epoch 32/100 Iteration: 29600 Avg. Training loss: 6.0945 0.0015 sec/batch
# Epoch 32/100 Iteration: 29700 Avg. Training loss: 6.0639 0.0060 sec/batch
# Epoch 32/100 Iteration: 29800 Avg. Training loss: 6.1384 0.0061 sec/batch
# Epoch 32/100 Iteration: 29900 Avg. Training loss: 6.2457 0.0057 sec/batch
# Epoch 32/100 Iteration: 30000 Avg. Training loss: 6.0929 0.0056 sec/batch
# Nearest to INS_LambdaExpression_ReturnStatement: INS_AnnotationTypeDeclaration_AnnotationTypeDeclaration MOVE_LambdaExpression MOVE_WildcardType INS_MethodInvocation_MethodInvocation DEL_CreationReference INS_ExpressionMethodReference_MethodInvocation INS_SimpleType_ArrayType INS_Initializer_EnumDeclaration
#
#
# Nearest to INS_ArrayCreation_ConditionalExpression: INS_NullLiteral_SuperConstructorInvocation INS_CastExpression_ArrayCreation INS_QualifiedName_ArrayCreation INS_MarkerAnnotation_VariableDeclarationStatement INS_PrimitiveType_ArrayType INS_QualifiedName_ConstructorInvocation INS_SimpleName_ConditionalExpression INS_Modifier_AnnotationTypeMemberDeclaration
#
#
# Nearest to MOVE_Javadoc: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_InstanceofExpression_WhileStatement: INS_Block_SynchronizedStatement MOVE_WildcardType INS_WhileStatement_SwitchStatement INS_SingleMemberAnnotation_AnnotationTypeDeclaration INS_CharacterLiteral_ArrayInitializer INS_PrimitiveType_ArrayType INS_ConditionalExpression_SwitchStatement INS_Javadoc_Initializer
#
#
# Nearest to INS_SwitchStatement_SwitchStatement: INS_SimpleType_TypeLiteral INS_ParenthesizedExpression_EnhancedForStatement INS_PrefixExpression_MethodInvocation INS_ParenthesizedExpression_IfStatement INS_InfixExpression_ArrayInitializer INS_SingleVariableDeclaration_MethodDeclaration INS_SimpleName_TagElement INS_TextElement_TextElement
#
#
# Nearest to INS_SimpleType_TypeParameter: MOVE_TypeParameter INS_InfixExpression_ArrayInitializer INS_AnnotationTypeDeclaration_AnnotationTypeDeclaration INS_BooleanLiteral_InfixExpression INS_ParameterizedType_ArrayType INS_MethodInvocation_PrefixExpression INS_CreationReference_MethodInvocation INS_TryStatement_IfStatement
#
#
# Nearest to INS_MethodInvocation_ConditionalExpression: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to DEL_TextElement:: INS_SimpleName_TagElement INS_ParameterizedType_TypeDeclaration MOVE_LambdaExpression DEL_PackageDeclaration INS_SimpleName_ClassInstanceCreation MOVE_TypeParameter DEL_ForStatement INS_InfixExpression_ArrayAccess
#
#
# Nearest to INS_TextElement_memory_starts: INS_AnnotationTypeDeclaration_AnnotationTypeDeclaration INS_StringLiteral_MemberValuePair INS_NormalAnnotation_FieldDeclaration INS_TypeLiteral_SuperConstructorInvocation INS_TagElement_TagElement INS_ArrayType_SingleVariableDeclaration INS_TypeDeclaration_AnonymousClassDeclaration INS_MethodRef_TagElement
#
#
# Nearest to DEL_ClassInstanceCreation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_SimpleName_SingleMemberAnnotation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_Block_CatchClause: INS_ParenthesizedExpression_FieldAccess INS_SingleMemberAnnotation_VariableDeclarationStatement INS_FieldAccess_Assignment INS_InfixExpression_ConditionalExpression INS_SimpleName_BreakStatement INS_ArrayInitializer_AnnotationTypeMemberDeclaration INS_StringLiteral_EnumConstantDeclaration INS_InstanceofExpression_VariableDeclarationFragment
#
#
# Nearest to MOVE_SuperConstructorInvocation: DEL_TypeParameter INS_Modifier_AnnotationTypeMemberDeclaration INS_MethodRefParameter_MethodRef INS_Block_MethodDeclaration INS_InfixExpression_ArrayCreation INS_NumberLiteral_SuperConstructorInvocation INS_QualifiedName_ImportDeclaration INS_Block_SynchronizedStatement
#
#
# Nearest to INS_CastExpression_ArrayCreation: DEL_Initializer INS_VariableDeclarationExpression_ForStatement INS_ArrayCreation_ConditionalExpression DEL_CharacterLiteral INS_TextElement_a_Collection INS_SimpleType_MethodInvocation INS_ParameterizedType_ArrayType DEL_ForStatement
#
#
# Nearest to INS_QualifiedName_ReturnStatement: INS_TextElement_run_the_compiler_in-process_in_Java,_you_should_look INS_NullLiteral_CastExpression INS_ParameterizedType_AnnotationTypeMemberDeclaration INS_Modifier_AnnotationTypeDeclaration INS_ArrayAccess_IfStatement INS_MethodInvocation_EnumConstantDeclaration MOVE_AnnotationTypeMemberDeclaration INS_TypeLiteral_VariableDeclarationFragment
#
#
# Nearest to INS_TextElement_TagElement: MOVE_MemberValuePair INS_TextElement:_do_so INS_Modifier_EnumDeclaration INS_SimpleName_SwitchCase INS_VariableDeclarationStatement_SwitchStatement INS_NumberLiteral_ReturnStatement INS_BooleanLiteral_SuperMethodInvocation DEL_TagElement
# Epoch 32/100 Iteration: 30100 Avg. Training loss: 5.9617 0.0058 sec/batch
# Epoch 32/100 Iteration: 30200 Avg. Training loss: 5.9304 0.0055 sec/batch
# Epoch 32/100 Iteration: 30300 Avg. Training loss: 5.9223 0.0058 sec/batch
# Epoch 32/100 Iteration: 30400 Avg. Training loss: 6.0083 0.0058 sec/batch
# Epoch 32/100 Iteration: 30500 Avg. Training loss: 5.8154 0.0056 sec/batch
# Epoch 33/100 Iteration: 30600 Avg. Training loss: 6.0818 0.0040 sec/batch
# Epoch 33/100 Iteration: 30700 Avg. Training loss: 5.8704 0.0056 sec/batch
# Epoch 33/100 Iteration: 30800 Avg. Training loss: 5.9247 0.0057 sec/batch
# Epoch 33/100 Iteration: 30900 Avg. Training loss: 5.9220 0.0058 sec/batch
# Epoch 33/100 Iteration: 31000 Avg. Training loss: 5.8472 0.0055 sec/batch
# Epoch 33/100 Iteration: 31100 Avg. Training loss: 5.5788 0.0054 sec/batch
# Epoch 33/100 Iteration: 31200 Avg. Training loss: 5.8044 0.0055 sec/batch
# Epoch 33/100 Iteration: 31300 Avg. Training loss: 5.6718 0.0056 sec/batch
# Epoch 33/100 Iteration: 31400 Avg. Training loss: 5.8169 0.0059 sec/batch
# Epoch 34/100 Iteration: 31500 Avg. Training loss: 5.9069 0.0010 sec/batch
# Epoch 34/100 Iteration: 31600 Avg. Training loss: 5.5865 0.0054 sec/batch
# Epoch 34/100 Iteration: 31700 Avg. Training loss: 5.7513 0.0056 sec/batch
# Epoch 34/100 Iteration: 31800 Avg. Training loss: 5.5441 0.0056 sec/batch
# Epoch 34/100 Iteration: 31900 Avg. Training loss: 5.5364 0.0055 sec/batch
# Epoch 34/100 Iteration: 32000 Avg. Training loss: 5.5756 0.0059 sec/batch
# Epoch 34/100 Iteration: 32100 Avg. Training loss: 5.3947 0.0055 sec/batch
# Epoch 34/100 Iteration: 32200 Avg. Training loss: 5.6157 0.0055 sec/batch
# Epoch 34/100 Iteration: 32300 Avg. Training loss: 5.4580 0.0056 sec/batch
# Epoch 34/100 Iteration: 32400 Avg. Training loss: 5.4989 0.0057 sec/batch
# Epoch 35/100 Iteration: 32500 Avg. Training loss: 5.5939 0.0039 sec/batch
# Epoch 35/100 Iteration: 32600 Avg. Training loss: 5.4464 0.0055 sec/batch
# Epoch 35/100 Iteration: 32700 Avg. Training loss: 5.4567 0.0056 sec/batch
# Epoch 35/100 Iteration: 32800 Avg. Training loss: 5.5265 0.0056 sec/batch
# Epoch 35/100 Iteration: 32900 Avg. Training loss: 5.4471 0.0057 sec/batch
# Epoch 35/100 Iteration: 33000 Avg. Training loss: 5.2578 0.0057 sec/batch
# Epoch 35/100 Iteration: 33100 Avg. Training loss: 5.3617 0.0055 sec/batch
# Epoch 35/100 Iteration: 33200 Avg. Training loss: 5.4099 0.0055 sec/batch
# Epoch 35/100 Iteration: 33300 Avg. Training loss: 5.3889 0.0055 sec/batch
# Epoch 36/100 Iteration: 33400 Avg. Training loss: 5.3817 0.0006 sec/batch
# Epoch 36/100 Iteration: 33500 Avg. Training loss: 5.4667 0.0058 sec/batch
# Epoch 36/100 Iteration: 33600 Avg. Training loss: 5.3732 0.0057 sec/batch
# Epoch 36/100 Iteration: 33700 Avg. Training loss: 5.4337 0.0055 sec/batch
# Epoch 36/100 Iteration: 33800 Avg. Training loss: 4.9990 0.0056 sec/batch
# Epoch 36/100 Iteration: 33900 Avg. Training loss: 5.0801 0.0055 sec/batch
# Epoch 36/100 Iteration: 34000 Avg. Training loss: 4.9940 0.0055 sec/batch
# Epoch 36/100 Iteration: 34100 Avg. Training loss: 5.1111 0.0059 sec/batch
# Epoch 36/100 Iteration: 34200 Avg. Training loss: 5.4134 0.0056 sec/batch
# Epoch 36/100 Iteration: 34300 Avg. Training loss: 5.0843 0.0056 sec/batch
# Epoch 37/100 Iteration: 34400 Avg. Training loss: 5.1924 0.0032 sec/batch
# Epoch 37/100 Iteration: 34500 Avg. Training loss: 4.9481 0.0057 sec/batch
# Epoch 37/100 Iteration: 34600 Avg. Training loss: 4.9632 0.0056 sec/batch
# Epoch 37/100 Iteration: 34700 Avg. Training loss: 5.0371 0.0056 sec/batch
# Epoch 37/100 Iteration: 34800 Avg. Training loss: 4.9573 0.0055 sec/batch
# Epoch 37/100 Iteration: 34900 Avg. Training loss: 5.2466 0.0056 sec/batch
# Epoch 37/100 Iteration: 35000 Avg. Training loss: 4.8793 0.0058 sec/batch
# Epoch 37/100 Iteration: 35100 Avg. Training loss: 4.9593 0.0057 sec/batch
# Epoch 37/100 Iteration: 35200 Avg. Training loss: 5.0881 0.0057 sec/batch
# Epoch 38/100 Iteration: 35300 Avg. Training loss: 4.9049 0.0001 sec/batch
# Epoch 38/100 Iteration: 35400 Avg. Training loss: 5.0232 0.0056 sec/batch
# Epoch 38/100 Iteration: 35500 Avg. Training loss: 5.1186 0.0057 sec/batch
# Epoch 38/100 Iteration: 35600 Avg. Training loss: 4.8699 0.0058 sec/batch
# Epoch 38/100 Iteration: 35700 Avg. Training loss: 4.8191 0.0056 sec/batch
# Epoch 38/100 Iteration: 35800 Avg. Training loss: 5.0036 0.0056 sec/batch
# Epoch 38/100 Iteration: 35900 Avg. Training loss: 4.8495 0.0056 sec/batch
# Epoch 38/100 Iteration: 36000 Avg. Training loss: 4.9376 0.0056 sec/batch
# Epoch 38/100 Iteration: 36100 Avg. Training loss: 4.8487 0.0056 sec/batch
# Epoch 38/100 Iteration: 36200 Avg. Training loss: 4.7244 0.0056 sec/batch
# Epoch 39/100 Iteration: 36300 Avg. Training loss: 4.8118 0.0028 sec/batch
# Epoch 39/100 Iteration: 36400 Avg. Training loss: 4.8449 0.0056 sec/batch
# Epoch 39/100 Iteration: 36500 Avg. Training loss: 4.9645 0.0057 sec/batch
# Epoch 39/100 Iteration: 36600 Avg. Training loss: 4.6550 0.0057 sec/batch
# Epoch 39/100 Iteration: 36700 Avg. Training loss: 4.7416 0.0056 sec/batch
# Epoch 39/100 Iteration: 36800 Avg. Training loss: 4.7394 0.0056 sec/batch
# Epoch 39/100 Iteration: 36900 Avg. Training loss: 4.7491 0.0054 sec/batch
# Epoch 39/100 Iteration: 37000 Avg. Training loss: 4.9127 0.0059 sec/batch
# Epoch 39/100 Iteration: 37100 Avg. Training loss: 4.6359 0.0056 sec/batch
# Epoch 39/100 Iteration: 37200 Avg. Training loss: 4.6430 0.0055 sec/batch
# Epoch 40/100 Iteration: 37300 Avg. Training loss: 4.6460 0.0052 sec/batch
# Epoch 40/100 Iteration: 37400 Avg. Training loss: 4.7188 0.0055 sec/batch
# Epoch 40/100 Iteration: 37500 Avg. Training loss: 4.6849 0.0056 sec/batch
# Epoch 40/100 Iteration: 37600 Avg. Training loss: 4.4682 0.0057 sec/batch
# Epoch 40/100 Iteration: 37700 Avg. Training loss: 4.7414 0.0056 sec/batch
# Epoch 40/100 Iteration: 37800 Avg. Training loss: 4.3937 0.0056 sec/batch
# Epoch 40/100 Iteration: 37900 Avg. Training loss: 4.6256 0.0056 sec/batch
# Epoch 40/100 Iteration: 38000 Avg. Training loss: 4.5699 0.0059 sec/batch
# Epoch 40/100 Iteration: 38100 Avg. Training loss: 4.6582 0.0058 sec/batch
# Epoch 41/100 Iteration: 38200 Avg. Training loss: 4.5582 0.0022 sec/batch
# Epoch 41/100 Iteration: 38300 Avg. Training loss: 4.5021 0.0055 sec/batch
# Epoch 41/100 Iteration: 38400 Avg. Training loss: 4.6025 0.0056 sec/batch
# Epoch 41/100 Iteration: 38500 Avg. Training loss: 4.5340 0.0057 sec/batch
# Epoch 41/100 Iteration: 38600 Avg. Training loss: 4.4458 0.0058 sec/batch
# Epoch 41/100 Iteration: 38700 Avg. Training loss: 4.5014 0.0060 sec/batch
# Epoch 41/100 Iteration: 38800 Avg. Training loss: 4.4294 0.0061 sec/batch
# Epoch 41/100 Iteration: 38900 Avg. Training loss: 4.4062 0.0059 sec/batch
# Epoch 41/100 Iteration: 39000 Avg. Training loss: 4.4915 0.0058 sec/batch
# Epoch 41/100 Iteration: 39100 Avg. Training loss: 4.3258 0.0058 sec/batch
# Epoch 42/100 Iteration: 39200 Avg. Training loss: 4.4843 0.0049 sec/batch
# Epoch 42/100 Iteration: 39300 Avg. Training loss: 4.4609 0.0058 sec/batch
# Epoch 42/100 Iteration: 39400 Avg. Training loss: 4.4090 0.0058 sec/batch
# Epoch 42/100 Iteration: 39500 Avg. Training loss: 4.3327 0.0058 sec/batch
# Epoch 42/100 Iteration: 39600 Avg. Training loss: 4.4401 0.0060 sec/batch
# Epoch 42/100 Iteration: 39700 Avg. Training loss: 4.3473 0.0059 sec/batch
# Epoch 42/100 Iteration: 39800 Avg. Training loss: 4.2998 0.0061 sec/batch
# Epoch 42/100 Iteration: 39900 Avg. Training loss: 4.3801 0.0061 sec/batch
# Epoch 42/100 Iteration: 40000 Avg. Training loss: 4.3751 0.0059 sec/batch
# Nearest to INS_LambdaExpression_ReturnStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_ArrayCreation_ConditionalExpression: INS_NullLiteral_ConditionalExpression INS_QualifiedName_AssertStatement INS_QualifiedName_ArrayCreation INS_AnnotationTypeMemberDeclaration_AnnotationTypeDeclaration INS_PrimitiveType_ArrayType INS_ArrayAccess_PostfixExpression INS_SimpleType_InstanceofExpression INS_InfixExpression_ConstructorInvocation
#
#
# Nearest to MOVE_Javadoc: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_InstanceofExpression_WhileStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_SwitchStatement_SwitchStatement: INS_SimpleType_TypeLiteral INS_PrefixExpression_MethodInvocation INS_QualifiedName_MethodRef INS_InfixExpression_ArrayInitializer INS_SingleVariableDeclaration_MethodDeclaration INS_NumberLiteral_PrefixExpression INS_SimpleName_TagElement INS_ParenthesizedExpression_IfStatement
#
#
# ...
# Epoch 86/100 Iteration: 81500 Avg. Training loss: 3.3971 0.0055 sec/batch
# Epoch 86/100 Iteration: 81600 Avg. Training loss: 3.4393 0.0058 sec/batch
# Epoch 86/100 Iteration: 81700 Avg. Training loss: 3.3569 0.0055 sec/batch
# Epoch 86/100 Iteration: 81800 Avg. Training loss: 3.4427 0.0057 sec/batch
# Epoch 86/100 Iteration: 81900 Avg. Training loss: 3.5265 0.0056 sec/batch
# Epoch 86/100 Iteration: 82000 Avg. Training loss: 3.4397 0.0057 sec/batch
# Epoch 87/100 Iteration: 82100 Avg. Training loss: 3.5254 0.0032 sec/batch
# Epoch 87/100 Iteration: 82200 Avg. Training loss: 3.3784 0.0055 sec/batch
# Epoch 87/100 Iteration: 82300 Avg. Training loss: 3.5767 0.0057 sec/batch
# Epoch 87/100 Iteration: 82400 Avg. Training loss: 3.4049 0.0057 sec/batch
# Epoch 87/100 Iteration: 82500 Avg. Training loss: 3.4017 0.0054 sec/batch
# Epoch 87/100 Iteration: 82600 Avg. Training loss: 3.5143 0.0055 sec/batch
# Epoch 87/100 Iteration: 82700 Avg. Training loss: 3.3517 0.0056 sec/batch
# Epoch 87/100 Iteration: 82800 Avg. Training loss: 3.4362 0.0057 sec/batch
# Epoch 87/100 Iteration: 82900 Avg. Training loss: 3.5436 0.0057 sec/batch
# Epoch 88/100 Iteration: 83000 Avg. Training loss: 3.4852 0.0001 sec/batch
# Epoch 88/100 Iteration: 83100 Avg. Training loss: 3.5349 0.0056 sec/batch
# Epoch 88/100 Iteration: 83200 Avg. Training loss: 3.4581 0.0057 sec/batch
# Epoch 88/100 Iteration: 83300 Avg. Training loss: 3.5137 0.0056 sec/batch
# Epoch 88/100 Iteration: 83400 Avg. Training loss: 3.4290 0.0054 sec/batch
# Epoch 88/100 Iteration: 83500 Avg. Training loss: 3.4441 0.0056 sec/batch
# Epoch 88/100 Iteration: 83600 Avg. Training loss: 3.3759 0.0056 sec/batch
# Epoch 88/100 Iteration: 83700 Avg. Training loss: 3.5425 0.0057 sec/batch
# Epoch 88/100 Iteration: 83800 Avg. Training loss: 3.4118 0.0058 sec/batch
# Epoch 88/100 Iteration: 83900 Avg. Training loss: 3.4571 0.0057 sec/batch
# Epoch 89/100 Iteration: 84000 Avg. Training loss: 3.5807 0.0027 sec/batch
# Epoch 89/100 Iteration: 84100 Avg. Training loss: 3.4507 0.0056 sec/batch
# Epoch 89/100 Iteration: 84200 Avg. Training loss: 3.4307 0.0057 sec/batch
# Epoch 89/100 Iteration: 84300 Avg. Training loss: 3.3654 0.0056 sec/batch
# Epoch 89/100 Iteration: 84400 Avg. Training loss: 3.3888 0.0054 sec/batch
# Epoch 89/100 Iteration: 84500 Avg. Training loss: 3.4078 0.0056 sec/batch
# Epoch 89/100 Iteration: 84600 Avg. Training loss: 3.4405 0.0056 sec/batch
# Epoch 89/100 Iteration: 84700 Avg. Training loss: 3.4841 0.0057 sec/batch
# Epoch 89/100 Iteration: 84800 Avg. Training loss: 3.4684 0.0057 sec/batch
# Epoch 89/100 Iteration: 84900 Avg. Training loss: 3.4916 0.0056 sec/batch
# Epoch 90/100 Iteration: 85000 Avg. Training loss: 3.5305 0.0053 sec/batch
# Epoch 90/100 Iteration: 85100 Avg. Training loss: 3.4744 0.0056 sec/batch
# Epoch 90/100 Iteration: 85200 Avg. Training loss: 3.4978 0.0057 sec/batch
# Epoch 90/100 Iteration: 85300 Avg. Training loss: 3.4404 0.0055 sec/batch
# Epoch 90/100 Iteration: 85400 Avg. Training loss: 3.4475 0.0057 sec/batch
# Epoch 90/100 Iteration: 85500 Avg. Training loss: 3.3263 0.0057 sec/batch
# Epoch 90/100 Iteration: 85600 Avg. Training loss: 3.4797 0.0057 sec/batch
# Epoch 90/100 Iteration: 85700 Avg. Training loss: 3.4003 0.0057 sec/batch
# Epoch 90/100 Iteration: 85800 Avg. Training loss: 3.4445 0.0056 sec/batch
# Epoch 91/100 Iteration: 85900 Avg. Training loss: 3.5665 0.0022 sec/batch
# Epoch 91/100 Iteration: 86000 Avg. Training loss: 3.4219 0.0057 sec/batch
# Epoch 91/100 Iteration: 86100 Avg. Training loss: 3.5402 0.0056 sec/batch
# Epoch 91/100 Iteration: 86200 Avg. Training loss: 3.3934 0.0057 sec/batch
# Epoch 91/100 Iteration: 86300 Avg. Training loss: 3.4284 0.0059 sec/batch
# Epoch 91/100 Iteration: 86400 Avg. Training loss: 3.4841 0.0058 sec/batch
# Epoch 91/100 Iteration: 86500 Avg. Training loss: 3.4238 0.0057 sec/batch
# Epoch 91/100 Iteration: 86600 Avg. Training loss: 3.4715 0.0056 sec/batch
# Epoch 91/100 Iteration: 86700 Avg. Training loss: 3.5082 0.0058 sec/batch
# Epoch 91/100 Iteration: 86800 Avg. Training loss: 3.4221 0.0056 sec/batch
# Epoch 92/100 Iteration: 86900 Avg. Training loss: 3.5232 0.0049 sec/batch
# Epoch 92/100 Iteration: 87000 Avg. Training loss: 3.3633 0.0054 sec/batch
# Epoch 92/100 Iteration: 87100 Avg. Training loss: 3.4564 0.0055 sec/batch
# Epoch 92/100 Iteration: 87200 Avg. Training loss: 3.3289 0.0056 sec/batch
# Epoch 92/100 Iteration: 87300 Avg. Training loss: 3.4911 0.0057 sec/batch
# Epoch 92/100 Iteration: 87400 Avg. Training loss: 3.3782 0.0056 sec/batch
# Epoch 92/100 Iteration: 87500 Avg. Training loss: 3.4352 0.0056 sec/batch
# Epoch 92/100 Iteration: 87600 Avg. Training loss: 3.4661 0.0056 sec/batch
# Epoch 92/100 Iteration: 87700 Avg. Training loss: 3.4793 0.0059 sec/batch
# Epoch 93/100 Iteration: 87800 Avg. Training loss: 3.5024 0.0019 sec/batch
# Epoch 93/100 Iteration: 87900 Avg. Training loss: 3.5194 0.0056 sec/batch
# Epoch 93/100 Iteration: 88000 Avg. Training loss: 3.4739 0.0055 sec/batch
# Epoch 93/100 Iteration: 88100 Avg. Training loss: 3.4054 0.0056 sec/batch
# Epoch 93/100 Iteration: 88200 Avg. Training loss: 3.4206 0.0057 sec/batch
# Epoch 93/100 Iteration: 88300 Avg. Training loss: 3.4394 0.0057 sec/batch
# Epoch 93/100 Iteration: 88400 Avg. Training loss: 3.3730 0.0056 sec/batch
# Epoch 93/100 Iteration: 88500 Avg. Training loss: 3.3622 0.0057 sec/batch
# Epoch 93/100 Iteration: 88600 Avg. Training loss: 3.5487 0.0056 sec/batch
# Epoch 93/100 Iteration: 88700 Avg. Training loss: 3.3378 0.0057 sec/batch
# Epoch 94/100 Iteration: 88800 Avg. Training loss: 3.5479 0.0043 sec/batch
# Epoch 94/100 Iteration: 88900 Avg. Training loss: 3.4604 0.0056 sec/batch
# Epoch 94/100 Iteration: 89000 Avg. Training loss: 3.4695 0.0055 sec/batch
# Epoch 94/100 Iteration: 89100 Avg. Training loss: 3.3576 0.0056 sec/batch
# Epoch 94/100 Iteration: 89200 Avg. Training loss: 3.4769 0.0058 sec/batch
# Epoch 94/100 Iteration: 89300 Avg. Training loss: 3.3327 0.0057 sec/batch
# Epoch 94/100 Iteration: 89400 Avg. Training loss: 3.5386 0.0057 sec/batch
# Epoch 94/100 Iteration: 89500 Avg. Training loss: 3.4635 0.0057 sec/batch
# Epoch 94/100 Iteration: 89600 Avg. Training loss: 3.4661 0.0057 sec/batch
# Epoch 95/100 Iteration: 89700 Avg. Training loss: 3.4899 0.0014 sec/batch
# Epoch 95/100 Iteration: 89800 Avg. Training loss: 3.5198 0.0055 sec/batch
# Epoch 95/100 Iteration: 89900 Avg. Training loss: 3.5048 0.0059 sec/batch
# Epoch 95/100 Iteration: 90000 Avg. Training loss: 3.4090 0.0057 sec/batch
# Nearest to INS_LambdaExpression_ReturnStatement: INS_VariableDeclarationFragment_FieldDeclaration INS_CharacterLiteral_ClassInstanceCreation INS_Initializer_AnonymousClassDeclaration INS_ThisExpression_ExpressionMethodReference INS_ParenthesizedExpression_EnhancedForStatement INS_TextElement_avoid_invoking_the_soy_compiler INS_PrimitiveType_FieldDeclaration INS_SimpleName_ArrayCreation
#
#
# Nearest to INS_ArrayCreation_ConditionalExpression: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to MOVE_Javadoc: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_InstanceofExpression_WhileStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_SwitchStatement_SwitchStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_SimpleType_TypeParameter: INS_MethodInvocation_PrefixExpression INS_SimpleName_InstanceofExpression INS_Initializer_AnonymousClassDeclaration DEL_EmptyStatement INS_NumberLiteral_SuperConstructorInvocation INS_CastExpression_ArrayInitializer INS_BooleanLiteral_AssertStatement INS_InfixExpression_ArrayInitializer
#
#
# Nearest to INS_MethodInvocation_ConditionalExpression: INS_QualifiedName_ImportDeclaration INS_VariableDeclarationFragment_FieldDeclaration INS_TypeLiteral_ArrayInitializer INS_ParenthesizedExpression_AssertStatement INS_StringLiteral_StringLiteral INS_MethodInvocation_DoStatement INS_DoStatement_SwitchStatement INS_DoStatement_Block
#
#
# Nearest to DEL_TextElement:: INS_SuperMethodInvocation_IfStatement INS_ParameterizedType_TypeDeclaration INS_ThrowStatement_IfStatement INS_SimpleName_SynchronizedStatement INS_TextElement_new_one_or_no_longer INS_ExpressionMethodReference_CastExpression INS_TryStatement_Block INS_ArrayCreation_ReturnStatement
#
#
# Nearest to INS_TextElement_memory_starts: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to DEL_ClassInstanceCreation: INS_ArrayType_SingleVariableDeclaration INS_ParameterizedType_ClassInstanceCreation INS_TypeLiteral_SingleMemberAnnotation INS_SimpleName:_MethodDeclaration INS_Javadoc_EnumDeclaration DEL_VariableDeclarationStatement INS_ConditionalExpression_SuperConstructorInvocation INS_CastExpression_ParenthesizedExpression
#
#
# Nearest to INS_SimpleName_SingleMemberAnnotation: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_Block_CatchClause: INS_SuperFieldAccess_Assignment INS_ThisExpression_ExpressionMethodReference INS_ParameterizedType_AnnotationTypeMemberDeclaration INS_SimpleName_InfixExpression INS_Assignment_ParenthesizedExpression INS_BooleanLiteral_AssertStatement INS_PrefixExpression_AssertStatement INS_TextElement_the_subject
#
#
# Nearest to MOVE_SuperConstructorInvocation: DEL_TypeParameter INS_QualifiedType_FieldDeclaration INS_QualifiedName_ImportDeclaration INS_LambdaExpression_ConditionalExpression INS_StringLiteral_VariableDeclarationFragment INS_TextElement_any_server MOVE_FieldDeclaration INS_ConditionalExpression_SuperConstructorInvocation
#
#
# Nearest to INS_CastExpression_ArrayCreation: INS_TextElement_a_Collection INS_EnhancedForStatement_SwitchStatement INS_ArrayInitializer_SingleMemberAnnotation INS_TextElement_be_positioned INS_ClassInstanceCreation_ConstructorInvocation INS_TextElement:_make_assertions_about_its_value DEL_Initializer INS_TextElement_validate_a_binding
#
#
# Nearest to INS_QualifiedName_ReturnStatement: INS_StringLiteral_AnnotationTypeMemberDeclaration INS_ParenthesizedExpression_ReturnStatement INS_NormalAnnotation_AnnotationTypeDeclaration INS_PrimitiveType_MethodRefParameter DEL_WildcardType INS_TypeLiteral_MethodInvocation INS_StringLiteral_EnumConstantDeclaration INS_NormalAnnotation_SingleVariableDeclaration
#
#
# Nearest to INS_TextElement_TagElement: INS_ArrayType_AnnotationTypeMemberDeclaration INS_EnumDeclaration_CompilationUnit DEL_TagElement INS_TextElement_be_dynamically_resolved_or_construtected INS_TextElement:_do_so INS_QualifiedName_ConditionalExpression INS_BooleanLiteral_IfStatement INS_TextElement_garbage_collect_this_class_loader,_but
# Epoch 95/100 Iteration: 90100 Avg. Training loss: 3.3739 0.0061 sec/batch
# Epoch 95/100 Iteration: 90200 Avg. Training loss: 3.4602 0.0063 sec/batch
# Epoch 95/100 Iteration: 90300 Avg. Training loss: 3.3682 0.0060 sec/batch
# Epoch 95/100 Iteration: 90400 Avg. Training loss: 3.4470 0.0059 sec/batch
# Epoch 95/100 Iteration: 90500 Avg. Training loss: 3.5460 0.0059 sec/batch
# Epoch 95/100 Iteration: 90600 Avg. Training loss: 3.4732 0.0059 sec/batch
# Epoch 96/100 Iteration: 90700 Avg. Training loss: 3.5308 0.0041 sec/batch
# Epoch 96/100 Iteration: 90800 Avg. Training loss: 3.4523 0.0058 sec/batch
# Epoch 96/100 Iteration: 90900 Avg. Training loss: 3.5391 0.0056 sec/batch
# Epoch 96/100 Iteration: 91000 Avg. Training loss: 3.3383 0.0057 sec/batch
# Epoch 96/100 Iteration: 91100 Avg. Training loss: 3.4603 0.0056 sec/batch
# Epoch 96/100 Iteration: 91200 Avg. Training loss: 3.3375 0.0057 sec/batch
# Epoch 96/100 Iteration: 91300 Avg. Training loss: 3.5643 0.0054 sec/batch
# Epoch 96/100 Iteration: 91400 Avg. Training loss: 3.4836 0.0057 sec/batch
# Epoch 96/100 Iteration: 91500 Avg. Training loss: 3.4720 0.0057 sec/batch
# Epoch 97/100 Iteration: 91600 Avg. Training loss: 3.5570 0.0009 sec/batch
# Epoch 97/100 Iteration: 91700 Avg. Training loss: 3.5230 0.0055 sec/batch
# Epoch 97/100 Iteration: 91800 Avg. Training loss: 3.5257 0.0055 sec/batch
# Epoch 97/100 Iteration: 91900 Avg. Training loss: 3.5012 0.0055 sec/batch
# Epoch 97/100 Iteration: 92000 Avg. Training loss: 3.3606 0.0055 sec/batch
# Epoch 97/100 Iteration: 92100 Avg. Training loss: 3.3933 0.0055 sec/batch
# Epoch 97/100 Iteration: 92200 Avg. Training loss: 3.3693 0.0061 sec/batch
# Epoch 97/100 Iteration: 92300 Avg. Training loss: 3.4855 0.0063 sec/batch
# Epoch 97/100 Iteration: 92400 Avg. Training loss: 3.4860 0.0060 sec/batch
# Epoch 97/100 Iteration: 92500 Avg. Training loss: 3.4658 0.0061 sec/batch
# Epoch 98/100 Iteration: 92600 Avg. Training loss: 3.5086 0.0037 sec/batch
# Epoch 98/100 Iteration: 92700 Avg. Training loss: 3.4123 0.0059 sec/batch
# Epoch 98/100 Iteration: 92800 Avg. Training loss: 3.4713 0.0060 sec/batch
# Epoch 98/100 Iteration: 92900 Avg. Training loss: 3.3353 0.0057 sec/batch
# Epoch 98/100 Iteration: 93000 Avg. Training loss: 3.4366 0.0057 sec/batch
# Epoch 98/100 Iteration: 93100 Avg. Training loss: 3.3760 0.0056 sec/batch
# Epoch 98/100 Iteration: 93200 Avg. Training loss: 3.4613 0.0057 sec/batch
# Epoch 98/100 Iteration: 93300 Avg. Training loss: 3.4701 0.0057 sec/batch
# Epoch 98/100 Iteration: 93400 Avg. Training loss: 3.4764 0.0057 sec/batch
# Epoch 99/100 Iteration: 93500 Avg. Training loss: 3.4807 0.0005 sec/batch
# Epoch 99/100 Iteration: 93600 Avg. Training loss: 3.6096 0.0056 sec/batch
# Epoch 99/100 Iteration: 93700 Avg. Training loss: 3.4785 0.0056 sec/batch
# Epoch 99/100 Iteration: 93800 Avg. Training loss: 3.4291 0.0056 sec/batch
# Epoch 99/100 Iteration: 93900 Avg. Training loss: 3.4341 0.0056 sec/batch
# Epoch 99/100 Iteration: 94000 Avg. Training loss: 3.4526 0.0056 sec/batch
# Epoch 99/100 Iteration: 94100 Avg. Training loss: 3.3922 0.0057 sec/batch
# Epoch 99/100 Iteration: 94200 Avg. Training loss: 3.4444 0.0057 sec/batch
# Epoch 99/100 Iteration: 94300 Avg. Training loss: 3.4386 0.0057 sec/batch
# Epoch 99/100 Iteration: 94400 Avg. Training loss: 3.4573 0.0058 sec/batch
# Epoch 100/100 Iteration: 94500 Avg. Training loss: 3.5128 0.0030 sec/batch
# Epoch 100/100 Iteration: 94600 Avg. Training loss: 3.4890 0.0057 sec/batch
# Epoch 100/100 Iteration: 94700 Avg. Training loss: 3.5143 0.0057 sec/batch
# Epoch 100/100 Iteration: 94800 Avg. Training loss: 3.3688 0.0059 sec/batch
# Epoch 100/100 Iteration: 94900 Avg. Training loss: 3.4401 0.0059 sec/batch
# Epoch 100/100 Iteration: 95000 Avg. Training loss: 3.4491 0.0058 sec/batch
# Epoch 100/100 Iteration: 95100 Avg. Training loss: 3.3322 0.0057 sec/batch
# Epoch 100/100 Iteration: 95200 Avg. Training loss: 3.5049 0.0057 sec/batch
# Epoch 100/100 Iteration: 95300 Avg. Training loss: 3.4523 0.0057 sec/batch
# Epoch 100/100 Iteration: 95400 Avg. Training loss: 3.4386 0.0056 sec/batch

# %% [markdown]
# ## Restore Embedding Matrix checkpoint
# This ensure that last training session is always used

# %%
with train_graph.as_default(): 
    saver = tf.train.Saver()
with tf.Session(graph=train_graph) as sess: 
    saver.restore(sess, tf.train.latest_checkpoint("checkpoints"))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\word_embeddings.ckpt

# %% [markdown]
# ## Store Pre-Trained Embeddings
# Pre-Trained Embeddings are stored in .txt file and used later on for looking up test embeddings.<br/>
#   **Note**: The previous embedding.txt file is deleted an re-written, with current checkpoint.<br/>
#   You need to execute **HYPERPARAMETERS** section to get *vocab_size*

# %%
embedding_filename = "embedding.txt"
if os.path.exists(embedding_filename): 
    os.remove(embedding_filename)
else:
    with open(embedding_filename, "w") as f: 
        for i in range(vocab_size): 
            _embed = embed_mat[i, :]
            embedded_word = rev_dic[i]
            f.write("%s %s\n"%(embedded_word, " ".join(map(str, _embed))))

# %% [markdown]
# ## Vizualize Data

# %%
# %config InlineBackend.figure_format = "retina"
from sklearn.manifold import TSNE 

def viz_data(embed_mat, reverse_dictionary, n_viz=20): 
    tsne = TSNE()
    embed_tsne = tsne.fit_transform(embed_mat[:n_viz, :])
    fig, ax  = plt.subplots(figsize=(14, 14))
    for idx in range(n_viz): 
        plt.scatter(*embed_tsne[idx, :], color="#ff8243")
        plt.annotate(reverse_dictionary[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
# Visualize pretrain data: 
viz_data(embed_mat, rev_dic)

# %% [markdown]
# ## Embedding Layer Utility Functions
# Here we define three functions to:
# - load embeddings as a dict
# - create a weight matrix for the Embedding layer from a loaded model

# %%
def load_embedding(filename):
    """
    load embedding as python dictionary {root<str>: embeddings<np_array>}
    :param filename: embedding.txt 
    :return: dictionary object mapping root to embeddings 
    """
    if not os.path.exists(filename): 
        print("please run 'Store Pre-Trained Embeddings Cell!'")
    else: 
        with open(filename, "r") as f: 
            lines = f.readlines()
            f.close()
            # create map of words to vectors 
            embedding = dict()
            for line in line: 
                comp = line.split()
                # map of <str, numpy array> 
                embedding[comp[0]] = np.asarray(comp[1:], dtype='float32')
    return embedding 

def get_weight_matrix(embedding, test_dic, embedding_size):
    """
    Create a weight matrix for the embedding layer from the Pre-Trained Embeddings 
    :param embedding: Pre-Trained emneddings dictionary 
    :param test_dic: vocabulary for test file 
    :param embedding_size: number of hidden layers, which can be found in HYPERPARAMETERS section 
    :return: embedding matrix of test file 
    """
    vocab_size = len(test_dic)
    # initialize embedding matrix with zeros for efficiency 
    embed_mat = np.zeros((vocab_size, embedding_size))
    # store vectors using the test dictionary integer mapping 
    for word, idx in test_dic.items(): 
        embed_mat[i] = embedding.get(word)
    return embed_mat

# %% [markdown]
# ## Load Test Dataset

# %%
test_folder_path = folder_path = 'C:\\Users\\ichel\\Desktop\\tmp_JSON_labeled_commits\\'
test_files = parse_json(test_folder_path)

# Get test dictionary objects 
test_dic, test_datas, test_freq_dict = preprocess_roots(test_files)
test_rev_dic = dict(zip(test_dic.values(), test_dic.keys()))

test_data = actions2sentence(test_datas)
tokenized_test_data = concat_train_data(test_data)
tokenized_test_data = tokenize_train_data(tokenized_test_data, test_dic)
print(tokenized_test_data[:10])
# Out:
# [78, 78, 387, 118, 193, 127, 69, 433, 78, 187]
